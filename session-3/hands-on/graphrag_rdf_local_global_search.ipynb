# %% [markdown]
# # Using SPARQL with Knowledge Graphs for RAG

# %% [markdown]
# ## Install Required Libraries

# %%
# !pip install -q rdflib==7.0.0 langchain==0.3.0 langchain-community==0.3.0 langchain-openai==0.2.0 langchain-chroma==0.1.4 chromadb==0.5.3
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Define Initial Question

# %%
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings
from typing import List

_ = load_dotenv()

# %%
question = "Give me the github link of Knowledge Graph Structure as Prompt"
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
query_embedding_vector = embeddings.embed_query(question)

# %% [markdown]
# ## Load RDF Graph
# Load the RDF graph from a Turtle file to initialize the graph structure.

# %%
from rdflib import Graph
from rdflib.plugins.sparql import prepareQuery
import pandas as pd

# Initialize RDF Graph
rdf_graph = Graph()

# Load the RDF graph from a fixed file (only done once)
rdf_graph.parse("global_graph.ttl", format="turtle")
print("RDF graph loaded successfully.")
# Out:
# RDF graph loaded successfully.

# %% [markdown]
# ## SPARQL Query Execution Function
# This function executes a given SPARQL query on the pre-loaded RDF graph and returns the results in a pandas DataFrame format.

# %%
def sparql_query(query: str) -> pd.DataFrame:
    """
    Executes a SPARQL query on a pre-loaded RDF graph and returns the results as a DataFrame.

    The function dynamically infers the column names from the query results.

    Parameters:
        query (str): The SPARQL query to execute.

    Returns:
        pd.DataFrame: A DataFrame containing the results of the SPARQL query.
    """
    try:
        # Prepare and execute the query        
        query = prepareQuery(query)
        results = rdf_graph.query(query)
        
        # Extract variable (column) names from the query result
        columns = results.vars  # Get the variable names from the query results
        
        # Process the results and convert them into a list of dictionaries
        data = []
        for row in results:
            row_data = {str(var): row[var] for var in columns}  # Dynamically build a row dict
            data.append(row_data)
        
        # Convert the data into a DataFrame
        df = pd.DataFrame(data, columns=[str(var) for var in columns])
        return df

    except Exception as e:
        print(f"An error occurred while executing the SPARQL query: {e}")
        return pd.DataFrame()

# %% [markdown]
# ## Initialize vector store
# Create a Chroma collection to store entities and their embeddings.

# %%
from langchain_chroma import Chroma
import chromadb
from tqdm import tqdm

# Initialize Chroma Persistent Client
persistent_client = chromadb.PersistentClient()
collection = persistent_client.get_or_create_collection(name="graphrag_collection")

# Execute the SPARQL query and get results as a DataFrame
query = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX onto: <http://example.org/ontology#>
    
    SELECT ?entity ?name ?type ?description ?description_embedding
    WHERE {
        # ?entity rdf:type onto:Entity .
        # ?entity onto:hasName ?name .
        # ?entity onto:hasType ?type .
        # ?entity onto:hasDescription ?description .
        # ?entity onto:hasDescriptionEmbedding ?description_embedding .
    }
"""
entities_df = sparql_query(query)

# Prepare data for Chroma collection
documents, metadatas, embeddings, ids = [], [], [], []

# Using tqdm for progress tracking
print("Processing entities and adding to Chroma collection...")
for _, row in tqdm(entities_df.iterrows(), total=len(entities_df), desc="Entities Processed"):
    documents.append(f"Name: {row['name']}, Type: {row['type']}, Description: {row['description']}")
    metadatas.append({
        'subject': str(row['entity']),
        'name': str(row['name']),
        'type': str(row['type']),
        'description': str(row['description'])
    })
    embeddings.append([float(x) for x in row['description_embedding'].split()])
    ids.append(str(row['entity']))

# Add the processed data to the Chroma collection
collection.add(
    documents=documents,
    metadatas=metadatas,
    embeddings=embeddings,
    ids=ids
)
print("Chroma collection populated successfully.")

# Initialize vector store using Chroma
vector_store = Chroma(client=persistent_client, collection_name="graphrag_collection")

# Verify the count of entries in the collection
print(f"Total entries in the collection: {vector_store._collection.count()}")
# Out:
# Processing entities and adding to Chroma collection...
# Entities Processed: 100%|██████████| 1140/1140 [00:02<00:00, 500.25it/s]
# Add of existing embedding ID: http://example.org/data#Entity_007dbb8cddf248268127b52e600ada04
# Add of existing embedding ID: http://example.org/data#Entity_008dce6bd1634d71bec32473e6e20afc
# Add of existing embedding ID: http://example.org/data#Entity_00c41e15396746689f430e63db124072
# Add of existing embedding ID: http://example.org/data#Entity_00d061cdff98409e966eff25bdde6468
# Add of existing embedding ID: http://example.org/data#Entity_0127aafb317e4c7aa0ab2994c1ff0d47
# Add of existing embedding ID: http://example.org/data#Entity_02846d01807c41628b8765a255ccc5e7
# Add of existing embedding ID: http://example.org/data#Entity_045e3b05d6cf4a599fa85caeb7893c7e
# Add of existing embedding ID: http://example.org/data#Entity_047fd5713ac5485fa2ac0be44c9f7e2c
# Add of existing embedding ID: http://example.org/data#Entity_04b59bb8f41d4184952e841543f4c0e4
# Add of existing embedding ID: http://example.org/data#Entity_058fa0a8f4f54b48ba007371d13c7d22
# Add of existing embedding ID: http://example.org/data#Entity_060a7e91aa5344c38fc902573fd6fff2
# Add of existing embedding ID: http://example.org/data#Entity_069ca33e06544c398389781c8c9207b4
# Add of existing embedding ID: http://example.org/data#Entity_06fe0a389dcc42beb40cb0313713c978
# Add of existing embedding ID: http://example.org/data#Entity_079268499e494276b2346607789d462d
# Add of existing embedding ID: http://example.org/data#Entity_0794b1c82f44480da5245ab25f5c3e7b
# Add of existing embedding ID: http://example.org/data#Entity_07ecdb28623d486aab28eccfacf0c0c6
# Add of existing embedding ID: http://example.org/data#Entity_08b5b794f4a04c0c8e3712d1ae5cf824
# Add of existing embedding ID: http://example.org/data#Entity_0999135062df4dae96b14201b84ef26b
# Add of existing embedding ID: http://example.org/data#Entity_0a09352bdb29462bbac660eb13cc52e9
# Add of existing embedding ID: http://example.org/data#Entity_0a443e367a46415dbdcb7a04b6c9c836
# Add of existing embedding ID: http://example.org/data#Entity_0aeceb6751b046a3a03b5c9215f82b5f
# Add of existing embedding ID: http://example.org/data#Entity_0c15441c017b4e7e9f8914f85df591c2
# Add of existing embedding ID: http://example.org/data#Entity_0c4386ed273c48c68032a410973be1a4
# Add of existing embedding ID: http://example.org/data#Entity_0c6132625a7f43c1b5c3001c66166816
# Add of existing embedding ID: http://example.org/data#Entity_0cd1a36bc485492da971cfa7395eb054
# Add of existing embedding ID: http://example.org/data#Entity_0d3ceab798ff4ea4b67c2c8672692bdb
# Add of existing embedding ID: http://example.org/data#Entity_0d9636e6973a4b3583a2213fea6b874e
# Add of existing embedding ID: http://example.org/data#Entity_0e5d97ad2b9b4914b9ff3421f661bc31
# Add of existing embedding ID: http://example.org/data#Entity_0f4b5dd9cff346748d76b27ced7f0dfe
# Add of existing embedding ID: http://example.org/data#Entity_0f7674fcc51b4bb6a2f4c9bcd85246ba
# Add of existing embedding ID: http://example.org/data#Entity_0fca6ca1c3bf45fcb8678c177b599839
# Add of existing embedding ID: http://example.org/data#Entity_10ac239fd05549099c71b35d5be9caff
# Add of existing embedding ID: http://example.org/data#Entity_1100f1480a184065bfa3dc0ca2e4ca6c
# Add of existing embedding ID: http://example.org/data#Entity_1111880fffc14a9b81c66b835e85baef
# Add of existing embedding ID: http://example.org/data#Entity_112d7a8c8614492ca8cf8650c47d9e6d
# Add of existing embedding ID: http://example.org/data#Entity_113813c4dfb641abbc94d0f8a027e350
# Add of existing embedding ID: http://example.org/data#Entity_11a2282ec70c42e0859ffe2e1f0a1ade
# Add of existing embedding ID: http://example.org/data#Entity_11cce3a985a94ae588655a6500090110
# Add of existing embedding ID: http://example.org/data#Entity_11f048d0f8354a049177c1abf2b380f5
# Add of existing embedding ID: http://example.org/data#Entity_11f96fc2f8f74cf5bdb7509bcbac69d7
# Add of existing embedding ID: http://example.org/data#Entity_12883dba1e554ee1a9ca774e700cf004
# Add of existing embedding ID: http://example.org/data#Entity_12c46dc9847840f482a583bca8496d1b
# Add of existing embedding ID: http://example.org/data#Entity_134f66344cf349ffae30ccd6668609f7
# Add of existing embedding ID: http://example.org/data#Entity_1520c86c7b46416f8a9ff419b09f7ff0
# Add of existing embedding ID: http://example.org/data#Entity_1647fdfc3c404b2e8ba772fe950e9320
# Add of existing embedding ID: http://example.org/data#Entity_17c2e127dfbb45979343f92acc902d38
# Add of existing embedding ID: http://example.org/data#Entity_18040f8a872d4c6e90e3175be119ffc1
# Add of existing embedding ID: http://example.org/data#Entity_185861a01375473b866bbb5a333f74a1
# Add of existing embedding ID: http://example.org/data#Entity_187216ea8dd14081962bf12c84332550
# Add of existing embedding ID: http://example.org/data#Entity_1881ad1867c54a2b9effffde0b56b88a
# Add of existing embedding ID: http://example.org/data#Entity_19bbfcbb635a4988bc1eaafb6b1388a0
# Add of existing embedding ID: http://example.org/data#Entity_1c26e0a24a1b4a23b37a304f81ea64d3
# Add of existing embedding ID: http://example.org/data#Entity_1e8672d7e22b49b5bdf72d2a8d3b95d0
# Add of existing embedding ID: http://example.org/data#Entity_1eeb55dda76043b5894031df299bff7d
# Add of existing embedding ID: http://example.org/data#Entity_1ef4b62ee7cb4cfd98eabc75339fb710
# Add of existing embedding ID: http://example.org/data#Entity_20acc190758b4dc0aededf067803d9bb
# Add of existing embedding ID: http://example.org/data#Entity_20adaea87c464a79adac78d253293273
# Add of existing embedding ID: http://example.org/data#Entity_20e20479aab84fb88d84eccbfa60536b
# Add of existing embedding ID: http://example.org/data#Entity_21098cf4933240dca3b2d7172c82e138
# Add of existing embedding ID: http://example.org/data#Entity_211ef6b51ddc4747bb7a000ad5d35e6a
# Add of existing embedding ID: http://example.org/data#Entity_223a3a042f874d138c92e669b21b56c0
# Add of existing embedding ID: http://example.org/data#Entity_2256072bffac4fad8d6d6590715b7d30
# Add of existing embedding ID: http://example.org/data#Entity_22c48f6d6b5942b29b4c4d3eb7f20d9c
# Add of existing embedding ID: http://example.org/data#Entity_230aa140d1434290ac7794751e2a0f4f
# Add of existing embedding ID: http://example.org/data#Entity_232be0e727fc4690af541c6c4739c943
# Add of existing embedding ID: http://example.org/data#Entity_234e598c13074c5c842f5ecc3360182a
# Add of existing embedding ID: http://example.org/data#Entity_234f2681360c4b80965aa0f4316cf348
# Add of existing embedding ID: http://example.org/data#Entity_23965a8602c749aca7b98dc080b4186f
# Add of existing embedding ID: http://example.org/data#Entity_23a290350c714c3ba19fd92457135774
# Add of existing embedding ID: http://example.org/data#Entity_23a6b75c55704dc8aa5bb915a3ed1434
# Add of existing embedding ID: http://example.org/data#Entity_24696079fae64d29857764649b18bc6e
# Add of existing embedding ID: http://example.org/data#Entity_25e55935c474456ea360c5db741f0c65
# Add of existing embedding ID: http://example.org/data#Entity_261e439235b046fc874ccbe6971595da
# Add of existing embedding ID: http://example.org/data#Entity_2654e8efd6604347bb86adbf17d0be24
# Add of existing embedding ID: http://example.org/data#Entity_26788db7fdcd48a595a85ffa838dbe03
# Add of existing embedding ID: http://example.org/data#Entity_275e8e933d0b438280597077a1a0df37
# Add of existing embedding ID: http://example.org/data#Entity_2788f8b630d3463d9263cae9943ca62e
# Add of existing embedding ID: http://example.org/data#Entity_279b45cc332a4989a350f7fae3a0bc03
# Add of existing embedding ID: http://example.org/data#Entity_27f281053f7b4d9d9944ea9f85c50648
# Add of existing embedding ID: http://example.org/data#Entity_28550a4b630c4400aba157aab480ffcb
# Add of existing embedding ID: http://example.org/data#Entity_2862b7f3c8b8403bb664c3d57d3fe7d4
# Add of existing embedding ID: http://example.org/data#Entity_293d5dfb5151462eaa3bde5d17e354cb
# Add of existing embedding ID: http://example.org/data#Entity_295aa72cef5540fcac7b16a69a3c08eb
# Add of existing embedding ID: http://example.org/data#Entity_2973daa35a6b4bd5a784aa9c4647c43d
# Add of existing embedding ID: http://example.org/data#Entity_2976ae1c599a4f24bc15637b11639b82
# Add of existing embedding ID: http://example.org/data#Entity_2ac8568bf6c0435d89c50a15f97b6b9b
# Add of existing embedding ID: http://example.org/data#Entity_2addabcc112745818cf82d838aac526e
# Add of existing embedding ID: http://example.org/data#Entity_2b48ee8248c94a4ab538c6c5b70b4918
# Add of existing embedding ID: http://example.org/data#Entity_2b78adc9dd824f44956f4c7101cecf7d
# Add of existing embedding ID: http://example.org/data#Entity_2baa2dfc86d64995a6cf0101e38b3c09
# Add of existing embedding ID: http://example.org/data#Entity_2c2d8c79d0634c6fa7f4148cedc51fe9
# Add of existing embedding ID: http://example.org/data#Entity_2c6afd161d8941e8956e0fbd8978ef2e
# Add of existing embedding ID: http://example.org/data#Entity_2d290bf0a54741feb460181307c560c7
# Add of existing embedding ID: http://example.org/data#Entity_2dfdbbbc9f7f4572a543406869df9604
# Add of existing embedding ID: http://example.org/data#Entity_3011612e1c1e4052842b5c940bfd9eec
# Add of existing embedding ID: http://example.org/data#Entity_305cc867cfce468f8c502be1488356e4
# Add of existing embedding ID: http://example.org/data#Entity_30b39defe9d34600b4b2f8fefa7657e0
# Add of existing embedding ID: http://example.org/data#Entity_31df336812af4bf0be6ec95df5966616
# Add of existing embedding ID: http://example.org/data#Entity_31e0494798d445b4893958ee5411d136
# Add of existing embedding ID: http://example.org/data#Entity_3210f6c9353b40538ce1b965ef67c53d
# Add of existing embedding ID: http://example.org/data#Entity_32c57985369e49619489eab7bbc9f916
# Add of existing embedding ID: http://example.org/data#Entity_32e6faa3c1ea4cb1b70c26e49c839f0a
# Add of existing embedding ID: http://example.org/data#Entity_337bb88c92ca4ba4884f3f73b678a530
# Add of existing embedding ID: http://example.org/data#Entity_34063b3a5c2e446685a060c8c638fc8e
# Add of existing embedding ID: http://example.org/data#Entity_354f9a1a584145e1ab032e4cba2a9287
# Add of existing embedding ID: http://example.org/data#Entity_3562997c67ab4080a0d8c32d9bd77e10
# Add of existing embedding ID: http://example.org/data#Entity_357fa7b3f52448329c478a03d04535e3
# Add of existing embedding ID: http://example.org/data#Entity_35b4ed8dd2fe43458bc3480a9440a3d6
# Add of existing embedding ID: http://example.org/data#Entity_35e04220d7e942f9ba007ad1b673900a
# Add of existing embedding ID: http://example.org/data#Entity_365c800950c7425ea4efe5791272aeb2
# Add of existing embedding ID: http://example.org/data#Entity_3719d57de30b46089431cb3734e3a316
# Add of existing embedding ID: http://example.org/data#Entity_371b17014c9541388a4f59db48039cad
# Add of existing embedding ID: http://example.org/data#Entity_374e509efa4b4d5e97169540cda9cc5a
# Add of existing embedding ID: http://example.org/data#Entity_389ff259998b409c952533de322ffa88
# Add of existing embedding ID: http://example.org/data#Entity_38bfbce5a0ba40f6be21dcafe9a96aaf
# Add of existing embedding ID: http://example.org/data#Entity_38ebc3eaa89842bdb6692e64f7d9530e
# Add of existing embedding ID: http://example.org/data#Entity_392c6f3c33e74c04b47aa792c8851e3e
# Add of existing embedding ID: http://example.org/data#Entity_3a297d2c6c7742748e74e1d5815eea6d
# Add of existing embedding ID: http://example.org/data#Entity_3ad1686187e64a0e824c4a57a5b0ed20
# Add of existing embedding ID: http://example.org/data#Entity_3b0140895b6641bfab189b9cbc4b999a
# Add of existing embedding ID: http://example.org/data#Entity_3c03321b84e643129a7c9ca3c2a9606b
# Add of existing embedding ID: http://example.org/data#Entity_3c35dbf328ad4b85b522c73c044f5a8f
# Add of existing embedding ID: http://example.org/data#Entity_3c4d6df9ef404cfda96425a4df0fb64c
# Add of existing embedding ID: http://example.org/data#Entity_3d9a0d6b773f4723a020a5e2145e2974
# Add of existing embedding ID: http://example.org/data#Entity_3debadfee85f46a8bc1bf37e33a7d761
# Add of existing embedding ID: http://example.org/data#Entity_3ed3da11d8d040059fc6e7dfd685f175
# Add of existing embedding ID: http://example.org/data#Entity_3f0e03a81dc346418a8f284ad4dbf0b8
# Add of existing embedding ID: http://example.org/data#Entity_3ff21aabbda54e049f99c75dcb00391a
# Add of existing embedding ID: http://example.org/data#Entity_403830ebbc4b4723a05f3ad4108a80e6
# Add of existing embedding ID: http://example.org/data#Entity_407e15d723144f9e9b927829e82ae905
# Add of existing embedding ID: http://example.org/data#Entity_41e0cc4aa370475f83de832d85fbbed7
# Add of existing embedding ID: http://example.org/data#Entity_41fedbe64cec49d4bfb5a56f8b2f1482
# Add of existing embedding ID: http://example.org/data#Entity_42084997d15a42e1b9c5c50753d0dec8
# Add of existing embedding ID: http://example.org/data#Entity_42a144f4ba044c77a32f7d69dbf8d555
# Add of existing embedding ID: http://example.org/data#Entity_438a9389d48f45a480548b72a29bcafe
# Add of existing embedding ID: http://example.org/data#Entity_440332064d1e479da8b72762af679f6a
# Add of existing embedding ID: http://example.org/data#Entity_448778f0c3d94f589ead85ecee0a698b
# Add of existing embedding ID: http://example.org/data#Entity_44af6fc786d74a23b0384d4105855d94
# Add of existing embedding ID: http://example.org/data#Entity_4571815ae70b4ffdbab412433e10a875
# Add of existing embedding ID: http://example.org/data#Entity_45a3ad15067148a0aa0d68fb77e3451a
# Add of existing embedding ID: http://example.org/data#Entity_4622e5f2e46d49889dbc975ad696edad
# Add of existing embedding ID: http://example.org/data#Entity_46303fbc973c41eebca5b8646d5ddb8a
# Add of existing embedding ID: http://example.org/data#Entity_464eab01adc84c62b3c48f8d0c46fd97
# Add of existing embedding ID: http://example.org/data#Entity_467869f30ad34811a19821c7bb84c8a6
# Add of existing embedding ID: http://example.org/data#Entity_478c88bf12394aea8b8f6bfd2bef2be3
# Add of existing embedding ID: http://example.org/data#Entity_49ac556071d546c798506f0e74ffa469
# Add of existing embedding ID: http://example.org/data#Entity_4a828aa866a4444eb0a17142a1b83aad
# Add of existing embedding ID: http://example.org/data#Entity_4b735b387bb5447d990eedede3415ac7
# Add of existing embedding ID: http://example.org/data#Entity_4ced97be0abe456a9cb1a151497e12d9
# Add of existing embedding ID: http://example.org/data#Entity_4d2cb2c9c2b5404392e197cd419f974e
# Add of existing embedding ID: http://example.org/data#Entity_4e2976693d1549aea7a47627203db960
# Add of existing embedding ID: http://example.org/data#Entity_4e4d46e1084b4ef68a9f61e055312809
# Add of existing embedding ID: http://example.org/data#Entity_4e6595244eab4e9191286c05177de543
# Add of existing embedding ID: http://example.org/data#Entity_4e69dc69bb2a45558c3b477d1cb6c09c
# Add of existing embedding ID: http://example.org/data#Entity_5019d4fbcd2c48568ff56baf28d81b90
# Add of existing embedding ID: http://example.org/data#Entity_507f2cd6343b43599baf91f444a9a00f
# Add of existing embedding ID: http://example.org/data#Entity_50c4ae73876a40879eb9c571589fdce7
# Add of existing embedding ID: http://example.org/data#Entity_51aecf9fbd694d4c8c35814529de3e23
# Add of existing embedding ID: http://example.org/data#Entity_52d0569733f94815af15c34507f5cf46
# Add of existing embedding ID: http://example.org/data#Entity_5331e629159143bcbede15e96a2d6b87
# Add of existing embedding ID: http://example.org/data#Entity_53801f6ea7344691809b802df15ee2e6
# Add of existing embedding ID: http://example.org/data#Entity_5397eb07fd2e44888c48d3123cd6b33f
# Add of existing embedding ID: http://example.org/data#Entity_53c56a722704401cbee71455558c9ad9
# Add of existing embedding ID: http://example.org/data#Entity_54e62cb9a19a41508d4fb5f11f043a59
# Add of existing embedding ID: http://example.org/data#Entity_557ffaa367c040df90a99840afd131fd
# Add of existing embedding ID: http://example.org/data#Entity_55dc01707bac40e49dcc651a8c448516
# Add of existing embedding ID: http://example.org/data#Entity_55e77112f7324a0e949459a40232ac17
# Add of existing embedding ID: http://example.org/data#Entity_560d9e9556c34175989b3545e771cca2
# Add of existing embedding ID: http://example.org/data#Entity_561f8aeae476498daa0035a4c78e1073
# Add of existing embedding ID: http://example.org/data#Entity_56d91b3db67345f2b32d72cf4d08dbdd
# Add of existing embedding ID: http://example.org/data#Entity_5749769f35fb4b80a3276caaa4f5d293
# Add of existing embedding ID: http://example.org/data#Entity_579aadd82ad9470680eed793238dc000
# Add of existing embedding ID: http://example.org/data#Entity_57e3b18e5c0d4e848aab1d138668942a
# Add of existing embedding ID: http://example.org/data#Entity_59541fa06a534e4ab40cec985e64785e
# Add of existing embedding ID: http://example.org/data#Entity_598bcdeb8f5749ec8a90f5ae4556fe22
# Add of existing embedding ID: http://example.org/data#Entity_5992e18d814b4d459eec2533b9418534
# Add of existing embedding ID: http://example.org/data#Entity_59987bd60f0a407c8c8e1c10cd6949f0
# Add of existing embedding ID: http://example.org/data#Entity_5ad12b7c649d4b9597078927a01fdd3d
# Add of existing embedding ID: http://example.org/data#Entity_5bc8425113de4549a6c3bd1274bbb754
# Add of existing embedding ID: http://example.org/data#Entity_5c8a907723c74650845c8b85c4ac131d
# Add of existing embedding ID: http://example.org/data#Entity_5c943042391446c4871655500990f0a5
# Add of existing embedding ID: http://example.org/data#Entity_5ce58de0525a47fc938fa6011c7f3073
# Add of existing embedding ID: http://example.org/data#Entity_5d01f9fdd25346c79421bb1e03bc3293
# Add of existing embedding ID: http://example.org/data#Entity_5d4f461d412c4d1eb88b6f63d1af9a34
# Add of existing embedding ID: http://example.org/data#Entity_5d856d69129a45e4b91c052818adc1f3
# Add of existing embedding ID: http://example.org/data#Entity_5d9894a87eb4402195d098cfca7f87d0
# Add of existing embedding ID: http://example.org/data#Entity_5de29ed46cb74f14945187864ad85edb
# Add of existing embedding ID: http://example.org/data#Entity_5df2e01fb7d7437893271cbe06e23a50
# Add of existing embedding ID: http://example.org/data#Entity_5ec66cff031a4e6b9e15f8cffddb81bf
# Add of existing embedding ID: http://example.org/data#Entity_5ed74211c1664b96ae476ad5ad533b34
# Add of existing embedding ID: http://example.org/data#Entity_612399732fbe42de881dd04d69420d50
# Add of existing embedding ID: http://example.org/data#Entity_624d862f550e437794902d53077a5ce9
# Add of existing embedding ID: http://example.org/data#Entity_626cf6e002a94b6cb60c3cb88c49d9fa
# Add of existing embedding ID: http://example.org/data#Entity_62e5a98faba648cb951dfb40380358e0
# Add of existing embedding ID: http://example.org/data#Entity_632e449f94194141a4505dba20ffe8cd
# Add of existing embedding ID: http://example.org/data#Entity_63a8cea77f57444990c1c4ca80e835db
# Add of existing embedding ID: http://example.org/data#Entity_63b2f3a3c0bd49c1b61e8a3c5eb0d04f
# Add of existing embedding ID: http://example.org/data#Entity_64df79f5ecf24e359a8a8723caa3e6d4
# Add of existing embedding ID: http://example.org/data#Entity_651828a1369d454399a87af6545abed0
# Add of existing embedding ID: http://example.org/data#Entity_6541d976e2ee42428d659d4344cbe2c2
# Add of existing embedding ID: http://example.org/data#Entity_65bee807e0db4ef9a24a9a2cc59be24c
# Add of existing embedding ID: http://example.org/data#Entity_6781298dd40f4f6693449c28bfe2cfdd
# Add of existing embedding ID: http://example.org/data#Entity_679f18816d4b4aaeac7da8f8e1a6a9f0
# Add of existing embedding ID: http://example.org/data#Entity_680f3d5100774060be92d15543dde454
# Add of existing embedding ID: http://example.org/data#Entity_69110b79e6624a02beb7f57f88a24870
# Add of existing embedding ID: http://example.org/data#Entity_6941d03cc0b9415790c01b0727b4c20d
# Add of existing embedding ID: http://example.org/data#Entity_696e6b15b41a4134af1b93a3a3fff211
# Add of existing embedding ID: http://example.org/data#Entity_6977ebf44e444382b1f7869068e1464f
# Add of existing embedding ID: http://example.org/data#Entity_6994d9aa17684a0194341bc2b418308b
# Add of existing embedding ID: http://example.org/data#Entity_69b5cd4738e34cb792091d63f00a4798
# Add of existing embedding ID: http://example.org/data#Entity_69c33d539db34fac813519f361524fb3
# Add of existing embedding ID: http://example.org/data#Entity_6aa11aa468854558a5c9d2eccd9ae5f5
# Add of existing embedding ID: http://example.org/data#Entity_6ad854d43d024c57a86e3a5ff10de3df
# Add of existing embedding ID: http://example.org/data#Entity_6b5847d47007497489b132960b5d083b
# Add of existing embedding ID: http://example.org/data#Entity_6d6c04af36334a66a1b745223611f96b
# Add of existing embedding ID: http://example.org/data#Entity_6dd5f35fd5e840cab4189859c9ce7da1
# Add of existing embedding ID: http://example.org/data#Entity_6df50b40c35141e98d260bfb01e740fa
# Add of existing embedding ID: http://example.org/data#Entity_6ed5a24c4d86438892ccd4259c502cbc
# Add of existing embedding ID: http://example.org/data#Entity_6f7ca30bd23348a488a5ddac62c95a74
# Add of existing embedding ID: http://example.org/data#Entity_6f93dac444434360ad21b99faffd5c5d
# Add of existing embedding ID: http://example.org/data#Entity_703c177a68c14181b376c6f87e8fa5ff
# Add of existing embedding ID: http://example.org/data#Entity_707da5fc31df457b9ec2f79727fef04f
# Add of existing embedding ID: http://example.org/data#Entity_70b8d1eb385f40a694d707ae944ae31e
# Add of existing embedding ID: http://example.org/data#Entity_70ff7b4ed5df407798f74daf3e9bcca4
# Add of existing embedding ID: http://example.org/data#Entity_7152d20436d144248ecd1b45763b76e3
# Add of existing embedding ID: http://example.org/data#Entity_7168e9b3046941feb2355ab8fa1df2fa
# Add of existing embedding ID: http://example.org/data#Entity_729f2c4830ab45e79c198a90bfb8f256
# Add of existing embedding ID: http://example.org/data#Entity_732cbee3298e4baca74ddf1355b1055e
# Add of existing embedding ID: http://example.org/data#Entity_7360b06a27204f1a99a17d082aba579e
# Add of existing embedding ID: http://example.org/data#Entity_74001886e6f8493f9ffe0e1b62bfdeb4
# Add of existing embedding ID: http://example.org/data#Entity_742b04547fc244e1ab04012807360b88
# Add of existing embedding ID: http://example.org/data#Entity_751f2c34a7464d039e0222785c7222de
# Add of existing embedding ID: http://example.org/data#Entity_75bdde8ba54647b4a78f3574ffbdcf26
# Add of existing embedding ID: http://example.org/data#Entity_75cd6498e5504aa18bcca90769f4b3f5
# Add of existing embedding ID: http://example.org/data#Entity_763dd1b731b54b83a85594016999e8b0
# Add of existing embedding ID: http://example.org/data#Entity_7644124d75d443a6857691fdafd1f88e
# Add of existing embedding ID: http://example.org/data#Entity_76f2f64e07d4463bbbcd0c36d57f52ba
# Add of existing embedding ID: http://example.org/data#Entity_7746bc48f3b8480ca7acd3afab3370f0
# Add of existing embedding ID: http://example.org/data#Entity_77806a02db5a462f94d5b2387525610a
# Add of existing embedding ID: http://example.org/data#Entity_77f04caae62746f9a84be4b971f15cbf
# Add of existing embedding ID: http://example.org/data#Entity_7823f05161d941ec85b6ed8742e52b33
# Add of existing embedding ID: http://example.org/data#Entity_7847bdb839d84a5d9b388d04062cfd9b
# Add of existing embedding ID: http://example.org/data#Entity_78be6c7a7e314039bc5e91e39071d28a
# Add of existing embedding ID: http://example.org/data#Entity_7959cdcf631e4606a689054df5dc7232
# Add of existing embedding ID: http://example.org/data#Entity_795b6335e17945c1881ec5ffaec54838
# Add of existing embedding ID: http://example.org/data#Entity_79c5e35ae85747a294646548baf81ae3
# Add of existing embedding ID: http://example.org/data#Entity_79e033bc6e8640ad9f4c79056f47300b
# Add of existing embedding ID: http://example.org/data#Entity_7a3e31bcbb0049d8ba1bae41776cffdf
# Add of existing embedding ID: http://example.org/data#Entity_7a752b3ba281421fa5122e724572c583
# Add of existing embedding ID: http://example.org/data#Entity_7af40b357094453c8ef0a33ded777032
# Add of existing embedding ID: http://example.org/data#Entity_7b024e33acab4d4c88a7307e88037b59
# Add of existing embedding ID: http://example.org/data#Entity_7bb2f81db5ea4de6b0aee429ab06d4ff
# Add of existing embedding ID: http://example.org/data#Entity_7c08572ef7254e8590cf35559c39fbdc
# Add of existing embedding ID: http://example.org/data#Entity_7c2067d2fce44fdf8882cc8980b67052
# Add of existing embedding ID: http://example.org/data#Entity_7c5ad0b26fd341058799124d3a9e3e1c
# Add of existing embedding ID: http://example.org/data#Entity_7caedca2d15144ce939db8b19fa6dc3d
# Add of existing embedding ID: http://example.org/data#Entity_7cb54a15cb8541b38fb7fe94c23bdc58
# Add of existing embedding ID: http://example.org/data#Entity_7cfb4429bf774dbcb32163c58cfd9a6e
# Add of existing embedding ID: http://example.org/data#Entity_7da17407acd3470f8c3af32b6a43b315
# Add of existing embedding ID: http://example.org/data#Entity_7da25d9a8dda42649112caa6a1cb3f55
# Add of existing embedding ID: http://example.org/data#Entity_7df04c99ea454001bb7cd34698aca382
# Add of existing embedding ID: http://example.org/data#Entity_7e11d886c5574116bf1cda70ae5320f5
# Add of existing embedding ID: http://example.org/data#Entity_7e766ea883bc4fb6b09554ea20644520
# Add of existing embedding ID: http://example.org/data#Entity_7e97a257e5274be2a487e5270a4dcbfc
# Add of existing embedding ID: http://example.org/data#Entity_8064023a4e97483c8b691f79a44f1eb1
# Add of existing embedding ID: http://example.org/data#Entity_818591bd94614efdaf1c9d22c0f3f8a6
# Add of existing embedding ID: http://example.org/data#Entity_81aa10c939e741388eca1d0570c890b6
# Add of existing embedding ID: http://example.org/data#Entity_81fee3f132774fcb8ab68517c7d54a2a
# Add of existing embedding ID: http://example.org/data#Entity_8292afefdee24861aa23983dd25977d6
# Add of existing embedding ID: http://example.org/data#Entity_82a1702bfc7745958a90864e7e78e01b
# Add of existing embedding ID: http://example.org/data#Entity_843b116801b246208ba08a03b1540232
# Add of existing embedding ID: http://example.org/data#Entity_858b7a9b7b7d4027aee1bcaf5e564af3
# Add of existing embedding ID: http://example.org/data#Entity_85b0f966a5cc40e68c3bd0426ad831dd
# Add of existing embedding ID: http://example.org/data#Entity_8680a636713b4afbbf3dacaadff882b1
# Add of existing embedding ID: http://example.org/data#Entity_8682d91b7a8048ddaf7a87976e0ffa3b
# Add of existing embedding ID: http://example.org/data#Entity_86b0657136034f0389b3cc524b6561d1
# Add of existing embedding ID: http://example.org/data#Entity_871544eb973e495399a9a06dcc70ac84
# Add of existing embedding ID: http://example.org/data#Entity_8750b205e0b646878a17349eb1c497f5
# Add of existing embedding ID: http://example.org/data#Entity_875713cc03474dff9a4870a23954d2a6
# Add of existing embedding ID: http://example.org/data#Entity_87ef0fcef893432fbc3efeb5f04a6a9b
# Add of existing embedding ID: http://example.org/data#Entity_881c0e748a9545349426071f6697d251
# Add of existing embedding ID: http://example.org/data#Entity_88d2a3417a964909b3746361e92519a1
# Add of existing embedding ID: http://example.org/data#Entity_89dc1a8423f04b77a922189fa20e18db
# Add of existing embedding ID: http://example.org/data#Entity_8acbb1f6b0a24c1798ee33b2a3b72532
# Add of existing embedding ID: http://example.org/data#Entity_8af3e2dfca4741478dea7fa124a27c43
# Add of existing embedding ID: http://example.org/data#Entity_8b6b098924254caea8bf94a85dd8db32
# Add of existing embedding ID: http://example.org/data#Entity_8c6a9c6e6a2746b6898f0dd0a48effbe
# Add of existing embedding ID: http://example.org/data#Entity_8d3dd7547c3343bab4a286ac1d3c0eec
# Add of existing embedding ID: http://example.org/data#Entity_8dea420408e042de81db641e177dec23
# Add of existing embedding ID: http://example.org/data#Entity_8dfa87c4c6d54a158cc1036a52caa525
# Add of existing embedding ID: http://example.org/data#Entity_8e24b19f529747288c5a556e087bc88a
# Add of existing embedding ID: http://example.org/data#Entity_8ea1ef0493614d3eb79baf43084cdd3e
# Add of existing embedding ID: http://example.org/data#Entity_90176fca59114b559cad3cb1dd8d39fb
# Add of existing embedding ID: http://example.org/data#Entity_903dfd0fdb4e4acabcedb54b4863f9a8
# Add of existing embedding ID: http://example.org/data#Entity_9057fcde1e224674b5ab2232df131a09
# Add of existing embedding ID: http://example.org/data#Entity_90bc0e6e64554e3ca991f094bb9cf617
# Add of existing embedding ID: http://example.org/data#Entity_919a515f2b864295b7a0d3ca9679ef1a
# Add of existing embedding ID: http://example.org/data#Entity_91fba8462fc44b96900effde7d92465e
# Add of existing embedding ID: http://example.org/data#Entity_926b490a483b44d1a87c2be545abc395
# Add of existing embedding ID: http://example.org/data#Entity_927f682bcf7645a9b2bcae97201db37c
# Add of existing embedding ID: http://example.org/data#Entity_92b78faadacb43a4b0949c7226fc9221
# Add of existing embedding ID: http://example.org/data#Entity_92e86306d3d1449a96c6eaec7dd74814
# Add of existing embedding ID: http://example.org/data#Entity_92f64886276342ed919cd5444a227d2c
# Add of existing embedding ID: http://example.org/data#Entity_934687f4fb334507b64d9b5007b67994
# Add of existing embedding ID: http://example.org/data#Entity_9479d496964842268efdf18ac7318e86
# Add of existing embedding ID: http://example.org/data#Entity_958e2e91bcf943d88cbf4a912cdc18f3
# Add of existing embedding ID: http://example.org/data#Entity_95a4aa9d448c47ccae58c95ffb1556ec
# Add of existing embedding ID: http://example.org/data#Entity_960121a324154a99b90fd15a2798e44e
# Add of existing embedding ID: http://example.org/data#Entity_965aeba7da1e4b44a0f6fb6c9c0038d9
# Add of existing embedding ID: http://example.org/data#Entity_970024a137ca48dc96e4cfa759b83f2c
# Add of existing embedding ID: http://example.org/data#Entity_973f680cf6fe4a409b6902cf11e87242
# Add of existing embedding ID: http://example.org/data#Entity_977b8b1a3a6b4c35be78cab6864f73fe
# Add of existing embedding ID: http://example.org/data#Entity_97906180f62341ae9acdd28736c89e7e
# Add of existing embedding ID: http://example.org/data#Entity_97e5f166602145e1bfd4c62c25082e1b
# Add of existing embedding ID: http://example.org/data#Entity_9872ff3c4d7f4aeabb4ade6f3849f29b
# Add of existing embedding ID: http://example.org/data#Entity_9a04d6f50dca46ffb1dfe17e7e250c72
# Add of existing embedding ID: http://example.org/data#Entity_9a3df79711484eac8c5f00f12d827474
# Add of existing embedding ID: http://example.org/data#Entity_9a744e11a3814f38a33eca9453dfa90b
# Add of existing embedding ID: http://example.org/data#Entity_9b8f2de46ab74247aaa0afad43d1ee0b
# Add of existing embedding ID: http://example.org/data#Entity_9c4a46164cbd42b580899dd4878346a1
# Add of existing embedding ID: http://example.org/data#Entity_9c6f476e9ac4423fa9622a49b2751a0e
# Add of existing embedding ID: http://example.org/data#Entity_9c7bfec3602744509ccdd3931960d659
# Add of existing embedding ID: http://example.org/data#Entity_9d86c2792f3542f2b2a91a0b5c25bd15
# Add of existing embedding ID: http://example.org/data#Entity_9da5302f519b403393a3fcb1b9e85fe5
# Add of existing embedding ID: http://example.org/data#Entity_9fd54eb48eaf48b5867fb215ff8ac1eb
# Add of existing embedding ID: http://example.org/data#Entity_9ffba6d44ab7403e817b74440b81a7b8
# Add of existing embedding ID: http://example.org/data#Entity_a0049468678440fbb098e00e46a8705d
# Add of existing embedding ID: http://example.org/data#Entity_a033da8c961344209b9185a1f232f671
# Add of existing embedding ID: http://example.org/data#Entity_a0824b5d628f4eecb761b40bfcfe23fb
# Add of existing embedding ID: http://example.org/data#Entity_a08a73cb15af41bba91731421eaaef2a
# Add of existing embedding ID: http://example.org/data#Entity_a0d314b039b74e7180687f0d4c46ecb1
# Add of existing embedding ID: http://example.org/data#Entity_a1a20c6b44ce41ccb25dcf7b5ae3423d
# Add of existing embedding ID: http://example.org/data#Entity_a2c13cc865db41b7ac0e9c2a79424199
# Add of existing embedding ID: http://example.org/data#Entity_a330ae834bed419a9e5603f7e43b31cb
# Add of existing embedding ID: http://example.org/data#Entity_a36a46e4b79f4a4bb8396a9bac465e4b
# Add of existing embedding ID: http://example.org/data#Entity_a3a162c34944458db90309545bf3de0d
# Add of existing embedding ID: http://example.org/data#Entity_a3ca8bdd09da4777915c4f8c257ae4e1
# Add of existing embedding ID: http://example.org/data#Entity_a3cb8748fd1c4bf78e85e59efd9f525a
# Add of existing embedding ID: http://example.org/data#Entity_a46e4fbcabfa4b7b926ed180f2ad60e1
# Add of existing embedding ID: http://example.org/data#Entity_a4f9c1fe81464d70ad6ce9ded0689fb0
# Add of existing embedding ID: http://example.org/data#Entity_a527d921657e42d3babcb12cdb1a7934
# Add of existing embedding ID: http://example.org/data#Entity_a5c2a229563b4e4597c8edbc6fe47668
# Add of existing embedding ID: http://example.org/data#Entity_a5cf15d149ca4e6db4d66cf32d589f9d
# Add of existing embedding ID: http://example.org/data#Entity_a62cfb7513f94b9f96b81b0b8287a2c0
# Add of existing embedding ID: http://example.org/data#Entity_a6b1397366904497b7cd9bf9e7c8620e
# Add of existing embedding ID: http://example.org/data#Entity_a735ca978d944378abcafa3152a95416
# Add of existing embedding ID: http://example.org/data#Entity_a74b9cf072a34f8c9895b757b5d6d3ab
# Add of existing embedding ID: http://example.org/data#Entity_a780dd9dc0da4a64951f4fff7a0e869f
# Add of existing embedding ID: http://example.org/data#Entity_a79385ff193f45da92c87fdec642fb96
# Add of existing embedding ID: http://example.org/data#Entity_a8f236632fca4b939d2b51ac843d2234
# Add of existing embedding ID: http://example.org/data#Entity_a935f83e34cf4a5bbce0717a90904397
# Add of existing embedding ID: http://example.org/data#Entity_a96a1ba69a554d29a8325b1a3e2e9b38
# Add of existing embedding ID: http://example.org/data#Entity_aa3544c4893c4e6d91d846d62fd99366
# Add of existing embedding ID: http://example.org/data#Entity_aa4a43facd9a4074a91b15a9389ddfab
# Add of existing embedding ID: http://example.org/data#Entity_aae36243e9364dcda49edb85fff5b754
# Add of existing embedding ID: http://example.org/data#Entity_ab54e1f987484993bc230c72ca3135d3
# Add of existing embedding ID: http://example.org/data#Entity_ab7259fec5c34d559539b3df6d01dd60
# Add of existing embedding ID: http://example.org/data#Entity_abe29f936f7f4d6e8ab9d32c9f5c1ec6
# Add of existing embedding ID: http://example.org/data#Entity_ac10b3ce451d4a6ba0669d7095b45a79
# Add of existing embedding ID: http://example.org/data#Entity_acaf8a19a52f4d42bb5c0579f1df869c
# Add of existing embedding ID: http://example.org/data#Entity_acd60320f2cb42c28e5f9a7e4be5e549
# Add of existing embedding ID: http://example.org/data#Entity_ad434ada4ab84efdbf39ed3fc8f91db8
# Add of existing embedding ID: http://example.org/data#Entity_ad663e7ced4444f6966bcb82955b7af1
# Add of existing embedding ID: http://example.org/data#Entity_adc7f36083724d6da9cd72471ca2fd08
# Add of existing embedding ID: http://example.org/data#Entity_addeb3873e4142688330557c5b768195
# Add of existing embedding ID: http://example.org/data#Entity_adf1860242224882b3ae83d3800b3f18
# Add of existing embedding ID: http://example.org/data#Entity_aea5dfb8ee5e479b9b3e947159b2a7c5
# Add of existing embedding ID: http://example.org/data#Entity_aecc013ce76d4fbcbadea1226557cf48
# Add of existing embedding ID: http://example.org/data#Entity_af026b4572264557bf359d40640c4cc0
# Add of existing embedding ID: http://example.org/data#Entity_af04e088f0ef488396eb0b47d44dc69d
# Add of existing embedding ID: http://example.org/data#Entity_af11ee0631234f95810ffcce2b25e24d
# Add of existing embedding ID: http://example.org/data#Entity_af5163a02e034f45b0fac637ce424f94
# Add of existing embedding ID: http://example.org/data#Entity_afd7aa4b6b834d5eb90e07d045979cf1
# Add of existing embedding ID: http://example.org/data#Entity_b05ec55bea6e4f46b7563956225423f4
# Add of existing embedding ID: http://example.org/data#Entity_b0e8612ca2384afa9cf6fb9dd65bbffc
# Add of existing embedding ID: http://example.org/data#Entity_b0fddf4ed35a4b65b8fecffb81abec6a
# Add of existing embedding ID: http://example.org/data#Entity_b1349dac80184c72890cb14aeeacfaed
# Add of existing embedding ID: http://example.org/data#Entity_b171a86540774ba89018a98e70f0fe64
# Add of existing embedding ID: http://example.org/data#Entity_b1a60745d74e4c90983deb727e422a83
# Add of existing embedding ID: http://example.org/data#Entity_b217a04caf104248a9b5526d5ad20b1f
# Add of existing embedding ID: http://example.org/data#Entity_b28d8909c93b4c4e9ae2422f995c3c53
# Add of existing embedding ID: http://example.org/data#Entity_b2d76ffeee08402989a50896d6046f48
# Add of existing embedding ID: http://example.org/data#Entity_b3c3bc471277445f8574a027c907fb11
# Add of existing embedding ID: http://example.org/data#Entity_b42c153b0c6d448f9fa41fceda3427fb
# Add of existing embedding ID: http://example.org/data#Entity_b4c8856dad2c45f0afc94a700f329d80
# Add of existing embedding ID: http://example.org/data#Entity_b54282f1661c4d1bbb701546dd5d503f
# Add of existing embedding ID: http://example.org/data#Entity_b5607912b1f845c288772cce4d1a2c16
# Add of existing embedding ID: http://example.org/data#Entity_b5788b18657a4e32aa285de0ae048c0e
# Add of existing embedding ID: http://example.org/data#Entity_b644364c69e045a3ab2f73affb19ba94
# Add of existing embedding ID: http://example.org/data#Entity_b6618ae91f2a488cac1f0530b50993f7
# Add of existing embedding ID: http://example.org/data#Entity_b723ce39c58c4c9d8268003cc47b8595
# Add of existing embedding ID: http://example.org/data#Entity_b747b4b976e442d88a419a497fbaa609
# Add of existing embedding ID: http://example.org/data#Entity_b7f91a284bdc4ced9ca027aa1d2a4d9d
# Add of existing embedding ID: http://example.org/data#Entity_b882427d51c249aeb7f92a52145a146c
# Add of existing embedding ID: http://example.org/data#Entity_b8d004fe48be47838df8b47323165cca
# Add of existing embedding ID: http://example.org/data#Entity_b90cc14afb894af7b37fe69fb4b9e53b
# Add of existing embedding ID: http://example.org/data#Entity_b9b942b1f1c8410fbe7ea02d084c494a
# Add of existing embedding ID: http://example.org/data#Entity_b9cfabb7109240b5baa96def4045810c
# Add of existing embedding ID: http://example.org/data#Entity_ba39a85e65a845b1bc9a18108b966107
# Add of existing embedding ID: http://example.org/data#Entity_ba815373024041a7b6641809152ba0c5
# Add of existing embedding ID: http://example.org/data#Entity_ba8c6b21dd704d6d875da58345e94860
# Add of existing embedding ID: http://example.org/data#Entity_bb22f3ab1978471db9e49780a68bd320
# Add of existing embedding ID: http://example.org/data#Entity_bbccca9834744cd4a815cab33d5ab942
# Add of existing embedding ID: http://example.org/data#Entity_bbe570cabbb24a96818f7d2854deac21
# Add of existing embedding ID: http://example.org/data#Entity_bc0042454d1e4e408a49ccb3cc82d8ce
# Add of existing embedding ID: http://example.org/data#Entity_bc6b9744de45414e9c7b0a09f55a652f
# Add of existing embedding ID: http://example.org/data#Entity_bcfaf2e5929844e98f4e1f5fca347241
# Add of existing embedding ID: http://example.org/data#Entity_bd5b2e1cdd38451499db1a8b4cc19037
# Add of existing embedding ID: http://example.org/data#Entity_bdd7b046509946e88bb015507af79973
# Add of existing embedding ID: http://example.org/data#Entity_be218abcb9254676bf468c092214dbb3
# Add of existing embedding ID: http://example.org/data#Entity_be67c5e8a471477792a423c275e8fc39
# Add of existing embedding ID: http://example.org/data#Entity_bea43fddd4f04fe2a0ae009a92edc428
# Add of existing embedding ID: http://example.org/data#Entity_beb71bf043e34e0f81bda043966fe937
# Add of existing embedding ID: http://example.org/data#Entity_bed0ff0e18b54b9fa2eec0e767a2ebb9
# Add of existing embedding ID: http://example.org/data#Entity_bef6b423a5ba41158da2a83b4e173eb8
# Add of existing embedding ID: http://example.org/data#Entity_bf8658015a9140119cf728d6443ad498
# Add of existing embedding ID: http://example.org/data#Entity_bfd28559b23f4da98b2f8954a2fe5558
# Add of existing embedding ID: http://example.org/data#Entity_bfda259e16bc44efb4ed76efc106bea7
# Add of existing embedding ID: http://example.org/data#Entity_c05bc8665eaa489dabda10df03273476
# Add of existing embedding ID: http://example.org/data#Entity_c06cd357989e4323a5ed22f850e0d7cd
# Add of existing embedding ID: http://example.org/data#Entity_c0ce6db11c864c578af6c010d1be576d
# Add of existing embedding ID: http://example.org/data#Entity_c10a142e2c9e47099e2f8dac90613366
# Add of existing embedding ID: http://example.org/data#Entity_c113db8f781d4fdbb257d1066bfeaaf7
# Add of existing embedding ID: http://example.org/data#Entity_c19531c2e6e64180840411a3872b1d92
# Add of existing embedding ID: http://example.org/data#Entity_c223d804b3a44f049b0b5254545da296
# Add of existing embedding ID: http://example.org/data#Entity_c232706483864221a2e0afd27d2b9bba
# Add of existing embedding ID: http://example.org/data#Entity_c32602cab91b4489b2249d88b587f4b9
# Add of existing embedding ID: http://example.org/data#Entity_c34f4b4ba93a418a81ef4e7fb72aff6c
# Add of existing embedding ID: http://example.org/data#Entity_c36b88d8906949db94f54c80379b53ce
# Add of existing embedding ID: http://example.org/data#Entity_c370aa790896462fbeec8d61fddce033
# Add of existing embedding ID: http://example.org/data#Entity_c3f406c8f0cd4748b491d118530b5a1f
# Add of existing embedding ID: http://example.org/data#Entity_c3fc60bd544f4e9f9894609c98ada6f1
# Add of existing embedding ID: http://example.org/data#Entity_c42e271d2c2f4bbe96f613fb6245d83b
# Add of existing embedding ID: http://example.org/data#Entity_c435f67e606848e599557f291725b0fa
# Add of existing embedding ID: http://example.org/data#Entity_c568754f7991418c9745e1fda4cdbe61
# Add of existing embedding ID: http://example.org/data#Entity_c56e309a18dd43c090d33e284350b562
# Add of existing embedding ID: http://example.org/data#Entity_c5a87c6344db4986a217512b0b4c65d2
# Add of existing embedding ID: http://example.org/data#Entity_c5b293c27cf7450689b97c719eb505df
# Add of existing embedding ID: http://example.org/data#Entity_c632a42bf90e41698ce98e5a8ce5ffc0
# Add of existing embedding ID: http://example.org/data#Entity_c6ad87075b0a41569fe54a6412527fce
# Add of existing embedding ID: http://example.org/data#Entity_c74b72762539419eb180dbaec54213d9
# Add of existing embedding ID: http://example.org/data#Entity_c7af4d3370e0489d9c6cb3b5441a3f3c
# Add of existing embedding ID: http://example.org/data#Entity_c7dbcc4f5edb42d6b8b55529ab478415
# Add of existing embedding ID: http://example.org/data#Entity_c7dd0336c1d74d768148e379cc37fb05
# Add of existing embedding ID: http://example.org/data#Entity_c8208820388042079bab20e6491c54a9
# Add of existing embedding ID: http://example.org/data#Entity_c846b0ced18040c2a1cf3daa4ebad260
# Add of existing embedding ID: http://example.org/data#Entity_c892d4e8ec9b4085b0122bbf1352e4f4
# Add of existing embedding ID: http://example.org/data#Entity_c9006d260b7e48e582b378aafba7557d
# Add of existing embedding ID: http://example.org/data#Entity_c9731ffaf58543da95f56ba57807ef9e
# Add of existing embedding ID: http://example.org/data#Entity_ca6c618306874dbb94da563ce0751810
# Add of existing embedding ID: http://example.org/data#Entity_cac6cb0f58794a7d92cee265f037a0b2
# Add of existing embedding ID: http://example.org/data#Entity_cace7b11b4104f9dbec65a926de1a971
# Add of existing embedding ID: http://example.org/data#Entity_cb2aa85f302f424aad375a195b096bcb
# Add of existing embedding ID: http://example.org/data#Entity_cb61f23e5c5047e7bb293ca9338df322
# Add of existing embedding ID: http://example.org/data#Entity_cbb914625a6e410687cffa649b98623b
# Add of existing embedding ID: http://example.org/data#Entity_cbc0c59487f940cbbfeb92afecb05dba
# Add of existing embedding ID: http://example.org/data#Entity_cbcd3a082f534fadbc6399ebd7746095
# Add of existing embedding ID: http://example.org/data#Entity_cc81ed70495343b6b22b57b097e85951
# Add of existing embedding ID: http://example.org/data#Entity_cccd6a402a3e48ab876a5ce7bdb144d1
# Add of existing embedding ID: http://example.org/data#Entity_cce56b8cedfa48e88825906b7e6b9109
# Add of existing embedding ID: http://example.org/data#Entity_cd51966311d94fba9b9022623fe4c453
# Add of existing embedding ID: http://example.org/data#Entity_cd5d3284dd954e0e8dbea5f21504215c
# Add of existing embedding ID: http://example.org/data#Entity_ce233829b6164445a47f8b66a9ff88be
# Add of existing embedding ID: http://example.org/data#Entity_ce99fe5ac09f4bfc8ab1c65e5ce4e71e
# Add of existing embedding ID: http://example.org/data#Entity_cea93f84149a4421bddd28bf6241c0b1
# Add of existing embedding ID: http://example.org/data#Entity_cf63341a3c804b498b8561a8d7178241
# Add of existing embedding ID: http://example.org/data#Entity_cf6994df9ea24b1db73ee0b6c3dfedb0
# Add of existing embedding ID: http://example.org/data#Entity_cfc71540c6764e77bcfecc7900e4777e
# Add of existing embedding ID: http://example.org/data#Entity_cfda2003d912496e8ecd94aceb95f216
# Add of existing embedding ID: http://example.org/data#Entity_d027ac50b4c949868cd1d9c2a89bd57c
# Add of existing embedding ID: http://example.org/data#Entity_d062b6fd224a4f43ad23208eb854f2e3
# Add of existing embedding ID: http://example.org/data#Entity_d0cb5e408ed14a4388db3188bf6a775d
# Add of existing embedding ID: http://example.org/data#Entity_d0efbf2b14eb4363b0a730b5269340fc
# Add of existing embedding ID: http://example.org/data#Entity_d106689439514a3e8cd8be39b111ade9
# Add of existing embedding ID: http://example.org/data#Entity_d1750a5d681044ebb3ef60d0e2daec7f
# Add of existing embedding ID: http://example.org/data#Entity_d1bd3b5fca354ce18791087e43cc2b69
# Add of existing embedding ID: http://example.org/data#Entity_d2af872f37754ed8afc09c138a529c2b
# Add of existing embedding ID: http://example.org/data#Entity_d2f3f1702e8d4393acfb319a0a876dd0
# Add of existing embedding ID: http://example.org/data#Entity_d36c9422d2a0497e82d2ef35f7d8da06
# Add of existing embedding ID: http://example.org/data#Entity_d424b264081045bdba686035e57969fc
# Add of existing embedding ID: http://example.org/data#Entity_d4375189dee64795af15626c69be6b5c
# Add of existing embedding ID: http://example.org/data#Entity_d4455f334c5c48a582c4bc4fb15a9f6a
# Add of existing embedding ID: http://example.org/data#Entity_d4aeae9e5f2443ae82d38ca1c9311d4f
# Add of existing embedding ID: http://example.org/data#Entity_d554e037ae334a03a68de3e353890be5
# Add of existing embedding ID: http://example.org/data#Entity_d5982bf57ac24125b34c8f22bdae496b
# Add of existing embedding ID: http://example.org/data#Entity_d5a5d37b4e0449cca857fcd7084862c9
# Add of existing embedding ID: http://example.org/data#Entity_d65c7284fb444130938b2dfe7150c6d0
# Add of existing embedding ID: http://example.org/data#Entity_d66f9588a374461d8751d0bfdf676944
# Add of existing embedding ID: http://example.org/data#Entity_d7bc0f66289042a788c1927946098254
# Add of existing embedding ID: http://example.org/data#Entity_d94a5011eef749f8926571ea0cdc2b1a
# Add of existing embedding ID: http://example.org/data#Entity_d9a59f7309404cb599c4825c2f937dd7
# Add of existing embedding ID: http://example.org/data#Entity_d9d7bc04c90046aa95be354c95db64c7
# Add of existing embedding ID: http://example.org/data#Entity_da032929c8f5491e9ae41664dc28301a
# Add of existing embedding ID: http://example.org/data#Entity_da394f4da65541fa95f3c58027ad5673
# Add of existing embedding ID: http://example.org/data#Entity_db7116af92b84100822b371dfdc2a023
# Add of existing embedding ID: http://example.org/data#Entity_dc5a9d221ccf40dfb75f1a0861d49def
# Add of existing embedding ID: http://example.org/data#Entity_dc5c823309a2424fa1991acee27478d7
# Add of existing embedding ID: http://example.org/data#Entity_de1d4047ca3a42d3ac4ee6e8a5013fec
# Add of existing embedding ID: http://example.org/data#Entity_de861df8dd5b473ea111be5489bb0389
# Add of existing embedding ID: http://example.org/data#Entity_df3065dbd4c640278120790a7b3e8505
# Add of existing embedding ID: http://example.org/data#Entity_dfa8440670754f2793481cd18d60af73
# Add of existing embedding ID: http://example.org/data#Entity_e03e16d7241b454692304450affbcf2a
# Add of existing embedding ID: http://example.org/data#Entity_e0a9bb419e4e468689979ace617b0833
# Add of existing embedding ID: http://example.org/data#Entity_e2060f70eb9945ed9ae94d97cf69616e
# Add of existing embedding ID: http://example.org/data#Entity_e2526824601242c489c973ad0a69dd5b
# Add of existing embedding ID: http://example.org/data#Entity_e285538fcc3c47ffabeebf88213a67b8
# Add of existing embedding ID: http://example.org/data#Entity_e4957b14386a49a1ba8292748a6d6ee0
# Add of existing embedding ID: http://example.org/data#Entity_e4f95bf029fb4306af1da9dfe9d4e861
# Add of existing embedding ID: http://example.org/data#Entity_e5287dd9f8164d1ea2dd00071930a564
# ...
# Add of existing embedding ID: http://example.org/data#Entity_9c675678212c4caabcef9adc41d97977
# Add of existing embedding ID: http://example.org/data#Entity_a04b3ad6d921482292975726990045ae
# Add of existing embedding ID: http://example.org/data#Entity_a567e2bacd0344dba2dc28bb0a09e1f8
# Add of existing embedding ID: http://example.org/data#Entity_a84ac6395acc4d169ae58b04ee98727f
# Add of existing embedding ID: http://example.org/data#Entity_a85311623ba148238ad24445e0ee08f1
# Add of existing embedding ID: http://example.org/data#Entity_b29e91c7b5074a83a9de1a7300d37046
# Add of existing embedding ID: http://example.org/data#Entity_b69fa25a802f49cf93c416b38498e505
# Add of existing embedding ID: http://example.org/data#Entity_c90c9739434549248836dc0f573999b1
# Add of existing embedding ID: http://example.org/data#Entity_e5702deed288489f970cbb23704b35ff
# Add of existing embedding ID: http://example.org/data#Entity_e69dce5ea9fc47898b41bce4315666c6
# Add of existing embedding ID: http://example.org/data#Entity_e8c41093ab7d410cb15b7acef7192950
# Add of existing embedding ID: http://example.org/data#Entity_f210427303a8486e87733ac902300b58
# Add of existing embedding ID: http://example.org/data#Entity_f3e5514f9858446a81be6b4bb29bfe76
# Add of existing embedding ID: http://example.org/data#Entity_f7cb0536b9494ca686cd4c314677c495
# Add of existing embedding ID: http://example.org/data#Entity_fbdd3926c97b4fbeb638e3d1705d4f0d
# Add of existing embedding ID: http://example.org/data#Entity_00d31cbe38044947bf605dd6132d8de1
# Add of existing embedding ID: http://example.org/data#Entity_0da0bb4c3d344cf283facd8b2db0aac5
# Add of existing embedding ID: http://example.org/data#Entity_1eb1b64761dc49a4bddba21a36cf4b56
# Add of existing embedding ID: http://example.org/data#Entity_1ef82d0b45dd4c8789b48b578391f91b
# Add of existing embedding ID: http://example.org/data#Entity_2f9a2233f62b4e10a83c214fe18c3d86
# Add of existing embedding ID: http://example.org/data#Entity_3bcefafcc6dc413a870c16cde6478e4c
# Add of existing embedding ID: http://example.org/data#Entity_4afe11a6550e46abbf521938148685cd
# Add of existing embedding ID: http://example.org/data#Entity_6b4b928e53e146abb427a256febc9b69
# Add of existing embedding ID: http://example.org/data#Entity_6f495b11aeed4b2d8cc33bacc494b803
# Add of existing embedding ID: http://example.org/data#Entity_792b0a5d1e62407a91aeb9f8005be25e
# Add of existing embedding ID: http://example.org/data#Entity_89915591ea584091aeceeb05e44d9191
# Add of existing embedding ID: http://example.org/data#Entity_90a72376fcfc45e48894172fb6dd7ab6
# Add of existing embedding ID: http://example.org/data#Entity_a48819fc083645008b4bc51d8dda085d
# Add of existing embedding ID: http://example.org/data#Entity_a4fb4d1268d64789a211d16efcdf8c8d
# Add of existing embedding ID: http://example.org/data#Entity_bfb10f12c78740ce815e34e0a3c58477
# Add of existing embedding ID: http://example.org/data#Entity_c309a50b1cb347aebcc044fe8b827336
# Add of existing embedding ID: http://example.org/data#Entity_d316a9328eb74b8181d61d6518775ad0
# Add of existing embedding ID: http://example.org/data#Entity_da7f99493b3f441f89e87361d9143706
# Add of existing embedding ID: http://example.org/data#Entity_e3500d7626854f66a3f46bdc30c869c9
# Add of existing embedding ID: http://example.org/data#Entity_fd2fc209d2a043faa98d1890a32743b3
# Add of existing embedding ID: http://example.org/data#Entity_fe0ccf15df4d49379d39379df49f3ce6
# Add of existing embedding ID: http://example.org/data#Entity_1c31f157d8c44095a00e9d636032c1ff
# Add of existing embedding ID: http://example.org/data#Entity_1f268c2fb47a439bbc4def9659724429
# Add of existing embedding ID: http://example.org/data#Entity_286a5a8a3a1a40f6b8a89f975d092602
# Add of existing embedding ID: http://example.org/data#Entity_289bce795ff043099dc3207788dad513
# Add of existing embedding ID: http://example.org/data#Entity_34bc5149d0df4c80a3b67c8266829dd8
# Add of existing embedding ID: http://example.org/data#Entity_3e836b8fa6344a10a64b64015c5739a8
# Add of existing embedding ID: http://example.org/data#Entity_4cc17cde363e489e96b5a06a125956fd
# Add of existing embedding ID: http://example.org/data#Entity_601f0bd2156c4b78aecf24bfce834529
# Add of existing embedding ID: http://example.org/data#Entity_84c581e2d5b648c08daae263e0ab61e0
# Add of existing embedding ID: http://example.org/data#Entity_9b54f167c654406184a85e46a5807911
# Add of existing embedding ID: http://example.org/data#Entity_b79e9001290b4c0a93da7155a862d5a6
# Add of existing embedding ID: http://example.org/data#Entity_d2be3307a9a048b18d87c094229b9d28
# Add of existing embedding ID: http://example.org/data#Entity_e30927ead49941b99fb7cbcea19224cc
# Add of existing embedding ID: http://example.org/data#Entity_eb9183ae4cca4e8c88667bef3e0bd2bb
# Add of existing embedding ID: http://example.org/data#Entity_edc32bee067242a1b69631170e5d38ba
# Add of existing embedding ID: http://example.org/data#Entity_ef641a60a4044eb09f020ef0d182f115
# Add of existing embedding ID: http://example.org/data#Entity_f25048ba99304759b21435b58c09b7df
# Add of existing embedding ID: http://example.org/data#Entity_f6ec66545d52467583d1a205af2d8ef0
# Add of existing embedding ID: http://example.org/data#Entity_1604aee93db74bce9c8e3dabdd3c6846
# Add of existing embedding ID: http://example.org/data#Entity_208ddb8b018d48c4a31b5dc48b8e16c3
# Add of existing embedding ID: http://example.org/data#Entity_3b8b1534562b428b852b59667c353d0a
# Add of existing embedding ID: http://example.org/data#Entity_60189ff2aec04a56a16558b245a4c080
# Add of existing embedding ID: http://example.org/data#Entity_6c27997fc82f4313ac2496c62c936a0f
# Add of existing embedding ID: http://example.org/data#Entity_770ae0ec3cd94dce8a66de1902f0b7aa
# Add of existing embedding ID: http://example.org/data#Entity_7da45a69f9544ab1ba521329e52c58f5
# Add of existing embedding ID: http://example.org/data#Entity_8c52bbf5787c48e5bc1400486dae2cb7
# Add of existing embedding ID: http://example.org/data#Entity_92b6772fe9de4deb89154417c8ab21ae
# Add of existing embedding ID: http://example.org/data#Entity_a93b8769581b469bb2547583012dbec7
# Add of existing embedding ID: http://example.org/data#Entity_ad56547479c44dcf9e51371b5713d581
# Add of existing embedding ID: http://example.org/data#Entity_b98712f340c4450a91f1010cf1836193
# Add of existing embedding ID: http://example.org/data#Entity_bd4447739eb74f139dfecd9e64aa2514
# Add of existing embedding ID: http://example.org/data#Entity_c65c77ee7c4744f296972539c3c10fee
# Add of existing embedding ID: http://example.org/data#Entity_e4ddec3e42014c07968099f42ba6e009
# Add of existing embedding ID: http://example.org/data#Entity_08b6288f955846c698b2e3dc2b946673
# Add of existing embedding ID: http://example.org/data#Entity_1e39a3b4e7114d7aaf50605a8b60c427
# Add of existing embedding ID: http://example.org/data#Entity_345d81e3bb3046d19dda977df10143d6
# Add of existing embedding ID: http://example.org/data#Entity_358cf97043e14fbd90ffd2fa6a42364c
# Add of existing embedding ID: http://example.org/data#Entity_3851927722c747b9b216d76b36976b26
# Add of existing embedding ID: http://example.org/data#Entity_3c9e2951bc2f4b3dbd6b953b7dad1dfa
# Add of existing embedding ID: http://example.org/data#Entity_434f100addea47fc9e4f6d7cadba6374
# Add of existing embedding ID: http://example.org/data#Entity_50917cda1bfd467f91a41caca13194f3
# Add of existing embedding ID: http://example.org/data#Entity_5787fefbd0854ae8abb3fa511f781841
# Add of existing embedding ID: http://example.org/data#Entity_665c351f602d483480329a82e62cf1a7
# Add of existing embedding ID: http://example.org/data#Entity_81dfc9e9996d4215a77bcfce5c46822b
# Add of existing embedding ID: http://example.org/data#Entity_9f0ad6c50ad048628ea8ddda85dc06a3
# Add of existing embedding ID: http://example.org/data#Entity_af1235c9cdd4484fbd0ac45e5ad6b15d
# Add of existing embedding ID: http://example.org/data#Entity_cf25b8bb4a33472f95989bf604587a7c
# Add of existing embedding ID: http://example.org/data#Entity_dd74da9776804071b381ca7fc6e619d4
# Add of existing embedding ID: http://example.org/data#Entity_e31fabb38d7b435b98a8d8d66ba61f90
# Add of existing embedding ID: http://example.org/data#Entity_e937a4450af546a59ea6be4d007be849
# Add of existing embedding ID: http://example.org/data#Entity_ef7c53ac45d249efaf40d3bc36ce2fa2
# Add of existing embedding ID: http://example.org/data#Entity_0eea71bc65cb47be87190fcba100c226
# Add of existing embedding ID: http://example.org/data#Entity_2c722b790b7b4d95b64e715d90c22778
# Add of existing embedding ID: http://example.org/data#Entity_6efa3bdbc50c4a118a2180d39d9a4af5
# Add of existing embedding ID: http://example.org/data#Entity_8b731737b9064964b1c0b479387f3bb6
# Add of existing embedding ID: http://example.org/data#Entity_a9582890340f47e38152ac2e1ccedb9e
# Add of existing embedding ID: http://example.org/data#Entity_c24c2c244d994e009de82e11d58ba72b
# Add of existing embedding ID: http://example.org/data#Entity_10b184e4a7fa481192dee9bdae3aa74c
# Add of existing embedding ID: http://example.org/data#Entity_64addcdb723a43c3b4cc7d8310641fdd
# Add of existing embedding ID: http://example.org/data#Entity_b182ff1119b54f0d97c10f1eeadee28f
# Add of existing embedding ID: http://example.org/data#Entity_bf528cdd1a7349f3967c1e72d7844d13
# Add of existing embedding ID: http://example.org/data#Entity_ea3e398635664cf3bcf8a72883e4c531
# Add of existing embedding ID: http://example.org/data#Entity_05a7e227c92948c8904550e7e16dfe07
# Add of existing embedding ID: http://example.org/data#Entity_14681e22ab7843098743cac9aa94b72b
# Add of existing embedding ID: http://example.org/data#Entity_21e413db703c445d9c280beeb70b3c91
# Add of existing embedding ID: http://example.org/data#Entity_2bb0e2e653b74e2bac19b04ca1b1feb8
# Add of existing embedding ID: http://example.org/data#Entity_9d78c2821cc442acb823351b7947ac1c
# Add of existing embedding ID: http://example.org/data#Entity_b3be7317d7b343efa345c19cb291b8d9
# Add of existing embedding ID: http://example.org/data#Entity_332297c439874348b9a721c9d9ecc117
# Add of existing embedding ID: http://example.org/data#Entity_60842b75fb8441a7aa2e9d641a5e7184
# Add of existing embedding ID: http://example.org/data#Entity_739800b2420f4afc889b1f3201d414bc
# Add of existing embedding ID: http://example.org/data#Entity_b397672df7c74530a2fc7dce71c077e4
# Add of existing embedding ID: http://example.org/data#Entity_e6b2314e4dfb4b2e90846b001a732af0
# Add of existing embedding ID: http://example.org/data#Entity_ec256271249244f4aed0a0c5dcbd1df8
# Add of existing embedding ID: http://example.org/data#Entity_1a594963a89140c288e3881675c9f11c
# Add of existing embedding ID: http://example.org/data#Entity_313ac21265b04789b56d27508c01ec97
# Add of existing embedding ID: http://example.org/data#Entity_433611e483be44d1b4b69ea81739a272
# Add of existing embedding ID: http://example.org/data#Entity_5109f25252794e48a96eaebee57bdee8
# Add of existing embedding ID: http://example.org/data#Entity_5bc4ac18edbd4b7aa3ee1ceebb970fcc
# Add of existing embedding ID: http://example.org/data#Entity_83c2ea8916234017a532ede5b515afe6
# Add of existing embedding ID: http://example.org/data#Entity_e73c72469a6f4dd0a3c7d294fa90fdff
# Add of existing embedding ID: http://example.org/data#Entity_355580ed20c34f4ca4f8887c778d2882
# Add of existing embedding ID: http://example.org/data#Entity_48a3e9bbc40b424da794d87c8766efe5
# Add of existing embedding ID: http://example.org/data#Entity_6172615065f447b0a9fd503f550e076f
# Add of existing embedding ID: http://example.org/data#Entity_97502c6ac29249b2a33edfbd939829b4
# Add of existing embedding ID: http://example.org/data#Entity_dde8166cfb6c4461a1adf2c45340b294
# Add of existing embedding ID: http://example.org/data#Entity_fc322101424144dbacf3b45da4ccbf50
# Add of existing embedding ID: http://example.org/data#Entity_2b628ac49db8460aac56e4d2f8ee54ed
# Add of existing embedding ID: http://example.org/data#Entity_4dd12751636e402ca8a25a497a33560e
# Add of existing embedding ID: http://example.org/data#Entity_7cdab8059115435ca2c8b4bf447ba539
# Add of existing embedding ID: http://example.org/data#Entity_8818ee4e3f394375a011ff4d7b26969e
# Add of existing embedding ID: http://example.org/data#Entity_9de2ab2afde845cfb9c280aa8b850f0a
# Add of existing embedding ID: http://example.org/data#Entity_a93d874b27d446ac8582c5632c839f79
# Add of existing embedding ID: http://example.org/data#Entity_fa17f4584e7d4461944b05f1eba845b6
# Add of existing embedding ID: http://example.org/data#Entity_aa06b8ff797241c18ecc24bb887a7479
# Add of existing embedding ID: http://example.org/data#Entity_b076e309066647dcbba7e3480c9eb2db
# Add of existing embedding ID: http://example.org/data#Entity_d19ee7f7b13f42a48d7e13c7e0c79229
# Add of existing embedding ID: http://example.org/data#Entity_dbe16f3a565d4700a8f5ee31cc8afb43
# Add of existing embedding ID: http://example.org/data#Entity_f2de73ee84f54f0c828c137fd5212d1a
# Add of existing embedding ID: http://example.org/data#Entity_b8fb2cf7557d4d03a07b4843bbe2c8b4
# Add of existing embedding ID: http://example.org/data#Entity_c83f9d06dba64030bedefbd74561e806
# Add of existing embedding ID: http://example.org/data#Entity_1a63765d1f0a435d8978751ddaf514ca
# Add of existing embedding ID: http://example.org/data#Entity_7b677443b9d54e7b8c0f0ba81227d215
# Add of existing embedding ID: http://example.org/data#Entity_aab055de704b480f82070d407ed1c2f0
# Add of existing embedding ID: http://example.org/data#Entity_dbc41f84f03e4a34b4592cb570564f61
# Add of existing embedding ID: http://example.org/data#Entity_aee97083b97e4c32bad4069e1eaa8c3e
# Add of existing embedding ID: http://example.org/data#Entity_b3db96b7e1c54f73a2605b28c5e381d9
# Add of existing embedding ID: http://example.org/data#Entity_c552bad4c4c2413f829caa0453b717d9
# Add of existing embedding ID: http://example.org/data#Entity_07cc6935a17b4de19c3ae33edbae3b2a
# Add of existing embedding ID: http://example.org/data#Entity_2bbcf9190ee0479e91436808bcd94397
# Add of existing embedding ID: http://example.org/data#Entity_39877868159442d78bb758dc09e3065d
# Add of existing embedding ID: http://example.org/data#Entity_d597816772ed48c4a11385d274190919
# Add of existing embedding ID: http://example.org/data#Entity_9494c9540d264a12b8c5481b28774b47
# Add of existing embedding ID: http://example.org/data#Entity_6b2140f92fbe46f29d5e557b30237c73
# Add of existing embedding ID: http://example.org/data#Entity_06d6d1c169074d688ce6068eefa5b18b
# Add of existing embedding ID: http://example.org/data#Entity_2f91968e03f943ce8666999dbb5efb00
# Add of existing embedding ID: http://example.org/data#Entity_e50cfa04ac664405996c166095ca53e1
# Add of existing embedding ID: http://example.org/data#Entity_476bbce9faa7491380feb1df48eec740
# Add of existing embedding ID: http://example.org/data#Entity_7a537c5b498143809f06f871978cc539
# Add of existing embedding ID: http://example.org/data#Entity_64503d8fe17d4bffb47427354952cef0
# Add of existing embedding ID: http://example.org/data#Entity_83038aca0c004377a9752de1e634d2ac
# Add of existing embedding ID: http://example.org/data#Entity_21802e2cc4f34299a0b1290a1228c7fb
# Add of existing embedding ID: http://example.org/data#Entity_4aa3d6b750804318a869f62cf0e7dd3a
# Add of existing embedding ID: http://example.org/data#Entity_1d5338db1a67407881baa0cf940887b5
# Add of existing embedding ID: http://example.org/data#Entity_ab9d5042668b414593722e2cc24fd7ba
# Add of existing embedding ID: http://example.org/data#Entity_cbf565b9a21947819981abe9c1391fb3
# Add of existing embedding ID: http://example.org/data#Entity_3fc048f8f02e45faa04821b2a2a1c29c
# Add of existing embedding ID: http://example.org/data#Entity_b69b548360384231bbe052efbd963029
# Add of existing embedding ID: http://example.org/data#Entity_751461e415634a14be842ab76d984710
# Add of existing embedding ID: http://example.org/data#Entity_d9a1a022a92447fdaf7514e6ef59fc22
# Add of existing embedding ID: http://example.org/data#Entity_89125e7e762444c2a30612c78472b4b1
# Add of existing embedding ID: http://example.org/data#Entity_80a509f9d40246ed9e8bdc939557e595
# Add of existing embedding ID: http://example.org/data#Entity_e8285b6bdc024251959d5dbb31fde927
# Chroma collection populated successfully.
# Total entries in the collection: 3725

# %% [markdown]
# ## Local Search
# ### Entity-based Reasoning
# The local search method uses both structured data from a knowledge graph and unstructured information from input documents to enhance the LLM's context during query processing. This method is particularly effective for questions involving detailed knowledge about specific entities, such as 'What are the healing properties of chamomile?'

# %% [markdown]
# Define the search limits for entities, chunks, communities, and relationships.

# %%
# adapt from https://github.com/ianormy/msft_graphrag_blog/blob/main/Part3/create_local_global.ipynb

TOP_ENTITIES = 10
TOP_CHUNKS = 10
TOP_COMMUNITIES = 3
TOP_OUTGOING_RELATIONSHIPS = 10
TOP_INCOMING_RELATIONSHIPS = 10

# %% [markdown]
# ### Find the top 10 nearest Entities
# Perform a k-nearest neighbor search using the vector store to identify the 10 most similar `Entity` instances based on the query embedding vector.

# %%
results = vector_store.similarity_search_by_vector(
    embedding=query_embedding_vector, k=TOP_ENTITIES
)

entity_list = [doc.metadata['subject'] for doc in results]
entity_list
# Out:
# ['http://example.org/data#Entity_fbdd7a2514b346c4ba3d23f63084db3b',
#  'http://example.org/data#Entity_f51482e3e86145a69bed79db525de5dd',
#  'http://example.org/data#Entity_434f100addea47fc9e4f6d7cadba6374',
#  'http://example.org/data#Entity_e0e9bca7e9694a92b35c435495aafa3d',
#  'http://example.org/data#Entity_8a66c7d217004b9ab2d18da75a395ba7',
#  'http://example.org/data#Entity_f3ed8363805f4b9e87c09bf5c737a478',
#  'http://example.org/data#Entity_157bb3947232453cbe97799a093e4e12',
#  'http://example.org/data#Entity_34fbaf58d70c4da0a622cfe0e535e95c',
#  'http://example.org/data#Entity_d19ee7f7b13f42a48d7e13c7e0c79229',
#  'http://example.org/data#Entity_5e991d98755446ec86ad8c2dfc689293']

# %%
def get_entities_query(entity_ids: List[str]) -> str:
    """
    Constructs a SPARQL query that retrieves entities based on a list of entity IDs.

    Parameters:
        entity_ids (list of str): A list of entity URIs to match.

    Returns:
        str: A SPARQL query string.
    """
    # Convert entity URIs into the SPARQL VALUES format
    values_clause = " ".join([f"<{entity_id}>" for entity_id in entity_ids])
    
    query = f"""
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX onto: <http://example.org/ontology#>
    
    SELECT ?human_readable_id ?name ?type ?description
    WHERE {{
        # ?entity rdf:type onto:Entity .
        # ?entity onto:hasName ?name .
        # ?entity onto:hasType ?type .
        # ?entity onto:hasDescription ?description .        
        # ?entity onto:hasHumanReadableId ?human_readable_id
                
        VALUES ?entity {{
            {values_clause}
        }}
    }}
    """
    
    return query

entities_df = sparql_query(get_entities_query(entity_list))
entities_df
# Out:
#   human_readable_id                    name                     type  \
# 0               370                      KG  DATA STRUCTURE, CONCEPT
# 1                62            KG STRUCTURE  CONCEPT, DATA STRUCTURE
# 2                70         GRAPH CONTEXT C  DATA STRUCTURE, CONTEXT
# 3                 4  KG STRUCTURE AS PROMPT        TECHNIQUE, METHOD
# 4               183        KNOWLEDGE GRAPHS  DATA STRUCTURE, CONCEPT
#
#                                          description
# 0  Knowledge Graphs (KGs) are data structures tha...
# 1  A knowledge graph structure used to represent ...
# 2  Context generated from knowledge graph structu...
# 3  KG STRUCTURE AS PROMPT" is a novel approach de...
# 4  Knowledge Graphs are graph-based structures us...

# %%
def dataframe_to_text(df: pd.DataFrame, column_delimiter: str = "|", context_name: str = "") -> str:
    """
    Converts a pandas DataFrame into a formatted text string representation, with an optional context header.

    Parameters:
        df (pd.DataFrame): The DataFrame to be converted.
        column_delimiter (str): The delimiter used to separate columns in the text output. Defaults to '|'.
        context_name (str): An optional context header to include at the top of the text output.

    Returns:
        str: A string representation of the DataFrame, including headers and rows, separated by the specified delimiter.
    """
    if df.empty:
        return ""

    header_text = f"-----{context_name}-----\n" if context_name else ""
    header_text += column_delimiter.join(df.columns) + "\n"
    rows_text = "\n".join(column_delimiter.join(map(str, row)) for row in df.values)

    return header_text + rows_text

# %%
entity_text = dataframe_to_text(entities_df, context_name='Entities')

# %% [markdown]
# ### Get The Top 10 Chunks(TextUnits)
# Retrieve the `TextUnit` records associated with the specified `Entity` instances. Rank these `TextUnit` records based on their frequency of association with the entities, and return the top 10 results.

# %%
def get_textunits_by_entities(entity_ids: List[str], limit_chunks: int = 3) -> str:
    """
    Constructs a SPARQL query that retrieves the top TextUnits connected to specified Entity records.

    Parameters:
        entity_ids (list of str): A list of entity IDs.
        limit_chunks (int): The maximum number of TextUnits to return.

    Returns:
        str: A SPARQL query string.
    """
    # Convert entity URIs into the SPARQL VALUES format
    values_clause = " ".join([f"<{entity_id}>" for entity_id in entity_ids])
    
    query = f"""
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX onto: <http://example.org/ontology#>
    PREFIX ex: <http://example.org/data#>

    SELECT ?textunit ?text (COUNT(?entity_uri) AS ?freq)
    WHERE {{
        
        VALUES ?entity_uri {{
            {values_clause}
        }}

        # ?entity_uri rdf:type onto:Entity .

        # ?textunit rdf:type onto:TextUnit ;
                  onto:hasText ?text ;
                  onto:referencesEntity ?entity_uri .
    }}
    GROUP BY ?textunit ?text
    ORDER BY DESC(?freq)
    LIMIT {limit_chunks}
    """
    
    return query

# %%
chunks_df = sparql_query(get_textunits_by_entities(entity_list, TOP_CHUNKS))
chunks_df
# Out:
#                                             textunit  \
# 0  http://example.org/data#TextUnit_5102919b3ad27...
# 1  http://example.org/data#TextUnit_056de216afa6e...
# 2  http://example.org/data#TextUnit_d3aa4f9c84bab...
# 3  http://example.org/data#TextUnit_2f64be1ed9bb8...
# 4  http://example.org/data#TextUnit_001576d5a1400...
# 5  http://example.org/data#TextUnit_aeec53dfc2004...
# 6  http://example.org/data#TextUnit_1a5bd10d2980f...
# 7  http://example.org/data#TextUnit_7c898119afbe1...
# 8  http://example.org/data#TextUnit_7f3a9f7fadb58...
# 9  http://example.org/data#TextUnit_9afd69f95819e...
#
#                                                 text freq
# 0  # Knowledge Graph Structure as Prompt: Improvi...    1
# 1   and an open-\r\n---\r\nKG Structure as Prompt...    1
# 2   content\r\nselection of the KG structures in ...    1
# 3   We think the reason is\r\nthat ordered candid...    1
# 4   the pair x and y as\r\ndefined in Eq. 3. Agai...    1
# 5   softmax layer are further applied on top of t...    1
# 6  .\r\n3. We develop an evaluation framework and...    1
# 7   domain-specific uses. On the one hand, it is ...    1
# 8   and Linguistic Computing 13(4), 177–186 (12 1...    1
# 9   knowledge graphs. In: Proc. of AAAI. vol. 35,...    1

# %%
chunk_text = dataframe_to_text(chunks_df, context_name='Chunks')

# %% [markdown]
# ### Get the Top 3 Communities
# Get the top 3 `Community` records that are related to these `Entity` records, including their community reports.

# %%
def get_communities_with_reports_by_entities(entity_ids: List[str], limit_communities: int = 3) -> str:
    """
    Constructs a SPARQL query that retrieves Communities and their associated Community Reports
    connected to specified Entity records, ordered by the rank in the community report.

    Parameters:
        entity_ids (list of str): A list of entity IDs.
        limit_communities (int): The maximum number of Communities to return.

    Returns:
        str: A SPARQL query string.
    """
    # Convert entity URIs into the SPARQL VALUES format
    values_clause = " ".join([f"<{entity_id}>" for entity_id in entity_ids])    
    query = f"""
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX onto: <http://example.org/ontology#>
    PREFIX ex: <http://example.org/data#>

    SELECT DISTINCT ?community ?report_title ?report_summary ?rank
    WHERE {{
        VALUES ?entity_uri {{
            {values_clause}
        }}

        # ?entity_uri rdf:type onto:Entity ;
                    onto:isInCommunity ?community .

        # ?community rdf:type onto:Community ;
                   onto:hasCommunityReport ?report .
                   
        # ?report rdf:type onto:CommunityReport ;
                onto:hasTitle ?report_title ;
                onto:hasSummary ?report_summary ;
                onto:hasRank ?rank .                    
    }}    
    ORDER BY DESC(?rank)
    LIMIT {limit_communities}
    """
    
    return query

# %%
reports_df = sparql_query(get_communities_with_reports_by_entities(entity_list, limit_communities=TOP_COMMUNITIES))
reports_df
# Out:
#                                community  \
# 0  http://example.org/data#Community_146
# 1    http://example.org/data#Community_7
# 2    http://example.org/data#Community_1
#
#                                         report_title  \
# 0  Knowledge Graphs and Large Language Models in ...
# 1  Large Language Models and Their Role in Algori...
# 2          Algorithmic Analysis and Knowledge Graphs
#
#                                       report_summary rank
# 0  The community of algorithmic analysis is signi...  9.0
# 1  The community of Large Language Models (LLMs) ...  9.0
# 2  The community of algorithmic analysis is intri...  9.0

# %%
reports_text = dataframe_to_text(reports_df, context_name='Reports')

# %% [markdown]
# ### Get Incoming and Outgoing Relationships for Entities
# Find the incoming and outgoing relationships for the selected `Entity` instances.

# %%
def get_outgoing_relationships(entity_ids: List[str], limit_outgoing_relationships: int = 10) -> str:
    """
    Constructs a SPARQL query that retrieves outgoing relationships where the specified entities are the source.

    Parameters:
        entity_ids (list of str): A list of Entity IDs.
        limit_outgoing_relationships (int): The maximum number of relationships to return.

    Returns:
        str: A SPARQL query string.
    """
    # Convert entity URIs into the SPARQL VALUES format
    values_clause = " ".join([f"<{entity_id}>" for entity_id in entity_ids])
    
    query = f"""
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX onto: <http://example.org/ontology#>
    PREFIX ex: <http://example.org/data#>

    SELECT ?human_readable_id ?source_name ?target_name ?description
    WHERE {{
        # ?relationship rdf:type onto:Relationship ;
                      onto:hasHumanReadableId ?human_readable_id ;
                      onto:hasDescription ?description ;
                      onto:source ?source_entity ;
                      onto:target ?target_entity ;
                      onto:hasSourceName ?source_name ;
                      onto:hasTargetName ?target_name ;
                      onto:hasRank ?rank ;
                      onto:hasWeight ?weight .

        VALUES ?source_entity {{
                {values_clause}
            }}        
    }}
    ORDER BY DESC(?rank) DESC(?weight)
    LIMIT {limit_outgoing_relationships}
    """
    
    return query

# %%
outgoing_relationships_df = sparql_query(get_outgoing_relationships(entity_list, TOP_OUTGOING_RELATIONSHIPS))
outgoing_relationships_df
# Out:
#   human_readable_id             source_name  \
# 0                70  KG STRUCTURE AS PROMPT
# 1               358        KNOWLEDGE GRAPHS
# 2               351        KNOWLEDGE GRAPHS
# 3               370        KNOWLEDGE GRAPHS
# 4               369        KNOWLEDGE GRAPHS
# 5               360        KNOWLEDGE GRAPHS
# 6               353        KNOWLEDGE GRAPHS
# 7               354        KNOWLEDGE GRAPHS
# 8               368        KNOWLEDGE GRAPHS
# 9               355        KNOWLEDGE GRAPHS
#
#                                    target_name  \
# 0                         KNOWLEDGE GRAPH (KG)
# 1                                         LORA
# 2                                       HITTER
# 3                    EVENT SEQUENCE GENERATION
# 4                       OL (ONTOLOGY LEARNING)
# 5                                         BART
# 6                                      MEM-KGC
# 7  CONVOLUTIONAL 2D KNOWLEDGE GRAPH EMBEDDINGS
# 8                                      DBPEDIA
# 9                                      COKG-QA
#
#                                          description
# 0  The approach uses structural information from ...
# 1  LoRA can be applied to large language models t...
# 2  HittER uses hierarchical transformers for know...
# 3  Event sequence generation is used to replicate...
# 4  Ontology Learning often involves extracting st...
# 5  BART can be used for natural language generati...
# 6  MEM-KGC is a model for knowledge graph completion
# 7  KNOWLEDGE GRAPHS are structured representation...
# 8  DBpedia is an example of a knowledge graph, re...
# 9  COKG-QA is a question answering system over CO...

# %%
def get_incoming_relationships(entity_ids: List[str], limit_incoming_relationships: int = 10) -> str:
    """
    Constructs a SPARQL query that retrieves incoming relationships where the specified entities are the target.

    Parameters:
        entity_ids (list of str): A list of Entity IDs.
        limit_incoming_relationships (int): The maximum number of relationships to return.

    Returns:
        str: A SPARQL query string.
    """
    # Convert entity URIs into the SPARQL VALUES format
    values_clause = " ".join([f"<{entity_id}>" for entity_id in entity_ids])
    
    query = f"""
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX onto: <http://example.org/ontology#>
    PREFIX ex: <http://example.org/data#>

    SELECT ?human_readable_id ?source_name ?target_name ?description
    WHERE {{
        # ?relationship rdf:type onto:Relationship ;          
                      onto:hasHumanReadableId ?human_readable_id ;
                      onto:hasDescription ?description ;
                      onto:source ?source_entity ;
                      onto:target ?target_entity ;
                      onto:hasSourceName ?source_name ;
                      onto:hasTargetName ?target_name ;
                      onto:hasRank ?rank ;
                      onto:hasWeight ?weight .        

        VALUES ?target_entity {{
            {values_clause}
        }}
        
    }}
    ORDER BY DESC(?rank) DESC(?weight)
    LIMIT {limit_incoming_relationships}
    """
    
    return query

# %%
incoming_relationships_df = sparql_query(get_incoming_relationships(entity_list, TOP_INCOMING_RELATIONSHIPS))
incoming_relationships_df
# Out:
#   human_readable_id                       source_name             target_name  \
# 0               461                              DIFT                      KG
# 1               137                           WORDNET        KNOWLEDGE GRAPHS
# 2               181                          WIKIDATA        KNOWLEDGE GRAPHS
# 3               127                              BERT        KNOWLEDGE GRAPHS
# 4               285                         METAPATHS        KNOWLEDGE GRAPHS
# 5               109             PROMPT-BASED LEARNING         GRAPH CONTEXT C
# 6               104             PROMPT-BASED LEARNING            KG STRUCTURE
# 7                61      SMALL LANGUAGE MODELS (SLMS)  KG STRUCTURE AS PROMPT
# 8                69  KNOWLEDGE-BASED CAUSAL DISCOVERY  KG STRUCTURE AS PROMPT
#
#                                          description
# 0  DIFT acquires knowledge from the KG to improve...
# 1  WordNet can be used as a resource in the const...
# 2  Wikidata is often used as a source for buildin...
# 3  BERT can be used for language understanding in...
# 4  Metapaths are used within knowledge graphs to ...
# 5  Graph context C is combined with input sequenc...
# 6  KG structure is used as a prompt in prompt-bas...
# 7  The "KG Structure as Prompt" approach signific...
# 8  The KG Structure as Prompt approach was evalua...

# %%
outgoing_relationships_text = dataframe_to_text(outgoing_relationships_df, context_name='Relationships')
incoming_relationships_text = dataframe_to_text(incoming_relationships_df)
relationships_text = outgoing_relationships_text + incoming_relationships_text

# %% [markdown]
# ### Create LangChain Response
# Having got all our important data for our identified entity list, we now need to combine them to produce a response that would be suitable as a LangChain response.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from tqdm import tqdm

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,    
)

# %% [markdown]
# ### Prompt with no context
# Prompt with no context fromt the Knowledge Graph

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a helpful assistant that answers questions about academic papers.",
        ),
        ("human", "{input}"),
    ]
)
chain = prompt | llm | StrOutputParser()
chain.invoke(
    {
        "input": question,
    }
)
# Out:
# 'The paper "Knowledge Graph Structure as Prompt" does not have a direct GitHub link provided in the information I have. To find the GitHub repository, if it exists, you can try the following steps:\n\n1. **Check the Paper**: Look at the paper itself, often in the introduction or conclusion sections, for any mention of supplementary materials or code repositories.\n\n2. **Search Online**: Use search engines with the paper\'s title along with "GitHub" to see if the authors have shared a link online.\n\n3. **Authors\' Profiles**: Visit the authors\' institutional or personal web pages, as they might host or link to the code there.\n\n4. **Research Repositories**: Websites like Papers with Code often list implementations of papers and might have a link to the GitHub repository if it exists.\n\nIf you have any more specific details or need further assistance, feel free to ask!'

# %% [markdown]
# ### Prompt with context retrieved from Knowledge Graph
# Create a context using the Knowledge Graph and feed that to the LLM.

# %%
# Source: https://github.com/microsoft/graphrag/blob/main/graphrag/query/structured_search/local_search/system_prompt.py

LOCAL_SEARCH_SYSTEM_PROMPT = """
---Role---

You are a helpful assistant responding to questions about data in the tables provided.


---Goal---

Generate a response of the target length and format that responds to the user's question, summarizing all information in the input data tables appropriate for the response length and format, and incorporating any relevant general knowledge.

If you don't know the answer, just say so. Do not make anything up.

Points supported by data should list their data references as follows:

"This is an example sentence supported by multiple data references [Data: <dataset name> (record ids); <dataset name> (record ids)]."

Do not list more than 5 record ids in a single reference. Instead, list the top 5 most relevant record ids and add "+more" to indicate that there are more.

For example:

"Person X is the owner of Company Y and subject to many allegations of wrongdoing [Data: Sources (15, 16), Reports (1), Entities (5, 7); Relationships (23); Claims (2, 7, 34, 46, 64, +more)]."

where 15, 16, 1, 5, 7, 23, 2, 7, 34, 46, and 64 represent the id (not the index) of the relevant data record.

Do not include information where the supporting evidence for it is not provided.


---Target response length and format---

{response_type}


---Data tables---

{context_data}


---Goal---

Generate a response of the target length and format that responds to the user's question, summarizing all information in the input data tables appropriate for the response length and format, and incorporating any relevant general knowledge.

If you don't know the answer, just say so. Do not make anything up.

Points supported by data should list their data references as follows:

"This is an example sentence supported by multiple data references [Data: <dataset name> (record ids); <dataset name> (record ids)]."

Do not list more than 5 record ids in a single reference. Instead, list the top 5 most relevant record ids and add "+more" to indicate that there are more.

For example:

"Person X is the owner of Company Y and subject to many allegations of wrongdoing [Data: Sources (15, 16), Reports (1), Entities (5, 7); Relationships (23); Claims (2, 7, 34, 46, 64, +more)]."

where 15, 16, 1, 5, 7, 23, 2, 7, 34, 46, and 64 represent the id (not the index) of the relevant data record.

Do not include information where the supporting evidence for it is not provided.


---Target response length and format---

{response_type}

Add sections and commentary to the response as appropriate for the length and format. Style the response in markdown.
"""

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            LOCAL_SEARCH_SYSTEM_PROMPT,
        ),
        (
            "human",
            "{question}",
        ),
    ]
)

chain = prompt | llm | StrOutputParser()
chain.invoke(
    {
        "response_type": "single paragraph",
        "context_data": entity_text + "\n" + chunk_text + "\n" + relationships_text +"\n" + reports_text,
        "question": question,
    }
)
# Out:
# 'The GitHub link for the "Knowledge Graph Structure as Prompt" approach is available at: [https://github.com/littleflow3r/kg-structure-as-prompt](https://github.com/littleflow3r/kg-structure-as-prompt) [Data: Chunks (5102919b3ad27254673948bab8a72ed8)].'

# %% [markdown]
# ## Global Search
#
# ### Whole Dataset Reasoning
# The global search method aggregates information from community reports in the knowledge graph to summarize themes and provide comprehensive answers. It works in a map-reduce manner: first, breaking down reports into smaller parts to generate intermediate responses (map step), and then combining the key points to form a final summary (reduce step). This approach is ideal for queries requiring an overview of the dataset, such as "What are the top 5 themes in the data?"

# %%
# Source: https://github.com/microsoft/graphrag/blob/main/graphrag/query/structured_search/global_search/map_system_prompt.py

MAP_SYSTEM_PROMPT = """
---Role---

You are a helpful assistant responding to questions about data in the tables provided.


---Goal---

Generate a response consisting of a list of key points that responds to the user's question, summarizing all relevant information in the input data tables.

You should use the data provided in the data tables below as the primary context for generating the response.
If you don't know the answer or if the input data tables do not contain sufficient information to provide an answer, just say so. Do not make anything up.

Each key point in the response should have the following element:
- Description: A comprehensive description of the point.
- Importance Score: An integer score between 0-100 that indicates how important the point is in answering the user's question. An 'I don't know' type of response should have a score of 0.

The response should be JSON formatted as follows:
{{
    "points": [
        {{"description": "Description of point 1 [Data: Reports (report ids)]", "score": score_value}},
        {{"description": "Description of point 2 [Data: Reports (report ids)]", "score": score_value}}
    ]
}}

The response shall preserve the original meaning and use of modal verbs such as "shall", "may" or "will".

Points supported by data should list the relevant reports as references as follows:
"This is an example sentence supported by data references [Data: Reports (report ids)]"

**Do not list more than 5 record ids in a single reference**. Instead, list the top 5 most relevant record ids and add "+more" to indicate that there are more.

For example:
"Person X is the owner of Company Y and subject to many allegations of wrongdoing [Data: Reports (2, 7, 64, 46, 34, +more)]. He is also CEO of company X [Data: Reports (1, 3)]"

where 1, 2, 3, 7, 34, 46, and 64 represent the id (not the index) of the relevant data report in the provided tables.

Do not include information where the supporting evidence for it is not provided.


---Data tables---

{context_data}

---Goal---

Generate a response consisting of a list of key points that responds to the user's question, summarizing all relevant information in the input data tables.

You should use the data provided in the data tables below as the primary context for generating the response.
If you don't know the answer or if the input data tables do not contain sufficient information to provide an answer, just say so. Do not make anything up.

Each key point in the response should have the following element:
- Description: A comprehensive description of the point.
- Importance Score: An integer score between 0-100 that indicates how important the point is in answering the user's question. An 'I don't know' type of response should have a score of 0.

The response shall preserve the original meaning and use of modal verbs such as "shall", "may" or "will".

Points supported by data should list the relevant reports as references as follows:
"This is an example sentence supported by data references [Data: Reports (report ids)]"

**Do not list more than 5 record ids in a single reference**. Instead, list the top 5 most relevant record ids and add "+more" to indicate that there are more.

For example:
"Person X is the owner of Company Y and subject to many allegations of wrongdoing [Data: Reports (2, 7, 64, 46, 34, +more)]. He is also CEO of company X [Data: Reports (1, 3)]"

where 1, 2, 3, 7, 34, 46, and 64 represent the id (not the index) of the relevant data report in the provided tables.

Do not include information where the supporting evidence for it is not provided.

The response should be JSON formatted as follows:
{{
    "points": [
        {{"description": "Description of point 1 [Data: Reports (report ids)]", "score": score_value}},
        {{"description": "Description of point 2 [Data: Reports (report ids)]", "score": score_value}}
    ]
}}
"""
map_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            MAP_SYSTEM_PROMPT,
        ),
        (
            "human",
            "{question}",
        ),
    ]
)
map_chain = map_prompt | llm | StrOutputParser()

# %%
REDUCE_SYSTEM_PROMPT = """
---Role---

You are a helpful assistant responding to questions about a dataset by synthesizing perspectives from multiple analysts.


---Goal---

Generate a response of the target length and format that responds to the user's question, summarize all the reports from multiple analysts who focused on different parts of the dataset.

Note that the analysts' reports provided below are ranked in the **descending order of importance**.

If you don't know the answer or if the provided reports do not contain sufficient information to provide an answer, just say so. Do not make anything up.

The final response should remove all irrelevant information from the analysts' reports and merge the cleaned information into a comprehensive answer that provides explanations of all the key points and implications appropriate for the response length and format.

Add sections and commentary to the response as appropriate for the length and format. Style the response in markdown.

The response shall preserve the original meaning and use of modal verbs such as "shall", "may" or "will".

The response should also preserve all the data references previously included in the analysts' reports, but do not mention the roles of multiple analysts in the analysis process.

**Do not list more than 5 record ids in a single reference**. Instead, list the top 5 most relevant record ids and add "+more" to indicate that there are more.

For example:

"Person X is the owner of Company Y and subject to many allegations of wrongdoing [Data: Reports (2, 7, 34, 46, 64, +more)]. He is also CEO of company X [Data: Reports (1, 3)]"

where 1, 2, 3, 7, 34, 46, and 64 represent the id (not the index) of the relevant data record.

Do not include information where the supporting evidence for it is not provided.


---Target response length and format---

{response_type}


---Analyst Reports---

{report_data}


---Goal---

Generate a response of the target length and format that responds to the user's question, summarize all the reports from multiple analysts who focused on different parts of the dataset.

Note that the analysts' reports provided below are ranked in the **descending order of importance**.

If you don't know the answer or if the provided reports do not contain sufficient information to provide an answer, just say so. Do not make anything up.

The final response should remove all irrelevant information from the analysts' reports and merge the cleaned information into a comprehensive answer that provides explanations of all the key points and implications appropriate for the response length and format.

The response shall preserve the original meaning and use of modal verbs such as "shall", "may" or "will".

The response should also preserve all the data references previously included in the analysts' reports, but do not mention the roles of multiple analysts in the analysis process.

**Do not list more than 5 record ids in a single reference**. Instead, list the top 5 most relevant record ids and add "+more" to indicate that there are more.

For example:

"Person X is the owner of Company Y and subject to many allegations of wrongdoing [Data: Reports (2, 7, 34, 46, 64, +more)]. He is also CEO of company X [Data: Reports (1, 3)]"

where 1, 2, 3, 7, 34, 46, and 64 represent the id (not the index) of the relevant data record.

Do not include information where the supporting evidence for it is not provided.


---Target response length and format---

{response_type}

Add sections and commentary to the response as appropriate for the length and format. Style the response in markdown.
"""

reduce_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            REDUCE_SYSTEM_PROMPT,
        ),
        (
            "human",
            "{question}",
        ),
    ]
)
reduce_chain = reduce_prompt | llm | StrOutputParser()

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

def global_retriever(query: str, level: int, response_type: str = "multiple paragraphs") -> str:
    """Global retriever

    :param query: the question as string
    :param level: the Community level
    :param response_type: type of response
    :returns: final response as a string
    """
    
    community_query = f"""
        PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
        PREFIX onto: <http://example.org/ontology#>
        PREFIX ex: <http://example.org/data#>

        SELECT ?full_content
        WHERE {{
            # ?community rdf:type onto:Community ;
                    onto:hasCommunityReport ?report .
                    
            # ?report rdf:type onto:CommunityReport ;
                    onto:hasFullContent ?full_content ;
                    onto:hasLevel ?level .

            FILTER(?level <= {level})   
        }}        
        """    
    reports_df = sparql_query(community_query)
    intermediate_results = []
    
    # for i in tqdm(range(len(reports_df)), desc="Processing communities"):        
    #     intermediate_response = map_chain.invoke(
    #         {"question": query, "context_data": reports_df["full_content"].iloc[i]}
    #     )
    #     intermediate_results.append(intermediate_response)

    def process_community(content):
        return map_chain.invoke({"question": query, "context_data": content})

    with ThreadPoolExecutor() as executor:
        futures = [executor.submit(process_community, reports_df["full_content"].iloc[i]) for i in range(len(reports_df))]
        for future in tqdm(as_completed(futures), total=len(futures), desc="Processing communities"):
            intermediate_results.append(future.result())

    final_response = reduce_chain.invoke(
        {
            "report_data": intermediate_results,
            "question": query,
            "response_type": response_type,
        }
    )
    return final_response

# %%
print(global_retriever("What are the main themes present in all these papers?", 0))
# Out:
# Processing communities: 100%|██████████| 25/25 [00:30<00:00,  1.23s/it]
# The main themes present in these papers revolve around advanced methodologies in algorithmic analysis, machine learning, and natural language processing. These themes are crucial for advancing the field and are prominently featured in conferences like ICML and EMNLP [Data: Reports (605, 847, 845, 846, 393, 543, 691, 692)].
#
# ### Algorithmic Analysis and Machine Learning
#
# A significant focus is on complex embeddings and subgraph reasoning, which are essential for tasks like link prediction and inductive relation prediction. These methodologies improve data retrieval and processing, enhancing the understanding of complex data structures [Data: Reports (605, 847, 845, 846, 650, 865)]. The integration of knowledge graphs in causal discovery and the use of models like GraIL and CoMPILE for inductive reasoning are also highlighted, showcasing the importance of structured data representations in algorithmic research [Data: Reports (511, 522, 523, 572, 571, 578, 577, 576)].
#
# ### Natural Language Processing
#
# In the realm of natural language processing, advancements in language models, including Falcon-40B and Roberta, are emphasized. These models are crucial for understanding and generating human language, and their development is a major focus in forums organized by the Association for Computational Linguistics (ACL) [Data: Reports (150, 168, 334, 326, 346)]. Few-shot text classification techniques and parameter-efficient prompt tuning are also significant themes, reflecting the community's commitment to developing more resource-efficient models [Data: Reports (189, 327, 378, 165, 342, 343)].
#
# ### Knowledge Graphs and Ontology Learning
#
# Knowledge graphs play a central role in these papers, serving as graph-based structures that efficiently represent and organize information. This is particularly relevant in fields like semantic web and artificial intelligence [Data: Entities (183), Relationships (137, 181, 285)]. Ontology learning and taxonomy discovery are also central themes, focusing on the organization and understanding of complex data structures through resources like WordNet and large language models (LLMs) [Data: Reports (26, 795, 137, 139, 141, +more)].
#
# ### Integration of Large Language Models
#
# The integration of large language models (LLMs) with knowledge graphs is a significant theme, highlighting how these models and graphs complement each other to enhance data processing and inference capabilities. This integration exemplifies the advanced combination of structured data and language processing, facilitating robust data analysis and knowledge representation [Data: Reports (12)]. Additionally, the role of LLMs in ontology learning and event sequence generation is notable, showcasing their ability to adapt and enhance domain-specific knowledge representation [Data: Reports (16, 24, 45, 46)].
#
# These themes collectively underscore the ongoing advancements in algorithmic research, machine learning, and natural language processing, highlighting the interdisciplinary nature of the research and its impact on various domains.
